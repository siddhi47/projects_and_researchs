# %% [markdown]
# # Association mining

# %% [markdown]
# <h1>Some Common terms</h1>
#
# <p> </p>
#
# <h2>Antecedent and consequent</h2>
# <p>
# Association rules provide information of this type in the form of if-then statements. These rules are computed from the data and, unlike the if-then rules of logic, association rules are probabilistic in nature.
# In addition to the antecedent (if) and the consequent (then), an association rule has two numbers that express the degree of uncertainty about the rule. In association analysis, the antecedent and consequent are sets of items (called itemsets) that are disjoint (do not have any items in common).</p>
#
# <h2>Support</h2>
# <p>The first number is called the support for the rule. The support is simply the number of transactions that include all items in the antecedent and consequent parts of the rule. The support is sometimes expressed as a percentage of the total number of records in the database.</p>
#
# <h2>Confidence</h2>
# <p>The other number is known as the confidence of the rule. Confidence is the ratio of the number of transactions that include all items in the consequent, as well as the antecedent (the support) to the number of transactions that include all items in the antecedent. </p>
# <h2>Lift</h2>
# <p>Lift is one more parameter of interest in the association analysis. Lift is nothing but the ratio of Confidence to Expected Confidence. Using the above example, expected Confidence in this case means, "confidence, if buying A and B does not enhance the probability of buying C."  It is the number of transactions that include the consequent divided by the total number of transactions.</p>
#
# <h2>Example</h2>
# <p>For example, if a supermarket database has 100,000 point-of-sale transactions, out of which 2,000 include both items A and B, and 800 of these include item C, the association rule "If A and B  are purchased, then C is purchased on the same trip," has a support of 800 transactions (alternatively 0.8% = 800/100,000), and a confidence of 40% (=800/2,000). One way to think of support is that it is the probability that a randomly selected transaction from the database will contain all items in the antecedent and the consequent, whereas the confidence is the conditional probability that a randomly selected transaction will include all the items in the consequent, given that the transaction includes all the items in the antecedent.</p>
# <p> Using the above example, expected Confidence in this case means, "confidence, if buying A and B does not enhance the probability of buying C."  It is the number of transactions that include the consequent divided by the total number of transactions. Suppose the number of total number of transactions for C are 5,000. Thus Expected Confidence is 5,000/1,00,000=5%. For the supermarket example the Lift = Confidence/Expected Confidence = 40%/5% = 8. Hence, Lift is a value that  gives us information about the increase in probability of the then (consequent)  given the if (antecedent) part.</p>
# <p><strong>A lift ratio larger than 1.0 implies that the relationship between the antecedent and the consequent is more significant than would be expected if the two sets were independent. The larger the lift ratio, the more significant the association.</strong></p>

# %% [markdown]
# # Randomly trying out algorithms

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
from apyori import apriori

# %%
data = pd.read_csv('zzz_user_tx_summary_product_crossselling1.txt',sep='|',error_bad_lines=False)
# Out:
# b'Skipping line 19440: expected 8 fields, saw 9\nSkipping line 28516: expected 8 fields, saw 9\nSkipping line 39732: expected 8 fields, saw 9\nSkipping line 59354: expected 8 fields, saw 10\nSkipping line 60335: expected 8 fields, saw 9\nSkipping line 61550: expected 8 fields, saw 9\nSkipping line 62286: expected 8 fields, saw 9\n'
# b'Skipping line 76107: expected 8 fields, saw 9\nSkipping line 95154: expected 8 fields, saw 9\nSkipping line 99512: expected 8 fields, saw 10\nSkipping line 113687: expected 8 fields, saw 10\nSkipping line 116525: expected 8 fields, saw 10\nSkipping line 119250: expected 8 fields, saw 9\nSkipping line 121225: expected 8 fields, saw 9\nSkipping line 121383: expected 8 fields, saw 9\nSkipping line 121740: expected 8 fields, saw 9\nSkipping line 122870: expected 8 fields, saw 9\nSkipping line 123767: expected 8 fields, saw 9\n'
8 fields, saw 9\nSkipping line 3001970: expected 8 fields, saw 9\nSkipping line 3002661: expected 8 fields, saw 9\nSkipping line 3002733: expected 8 fields, saw 9\nSkipping line 3004097: expected 8 fields, saw 9\nSkipping line 3005373: expected 8 fields, saw 9\nSkipping line 3005797: expected 8 fields, saw 9\nSkipping line 3005940: expected 8 fields, saw 9\nSkipping line 3006783: expected 8 fields, saw 9\nSkipping line 3006928: expected 8 fields, saw 9\nSkipping line 3007147: expected 8 fields, saw 9\nSkipping line 3007302: expected 8 fields, saw 9\nSkipping line 3007412: expected 8 fields, saw 9\nSkipping line 3007776: expected 8 fields, saw 9\nSkipping line 3008808: expected 8 fields, saw 9\nSkipping line 3008956: expected 8 fields, saw 9\nSkipping line 3009396: expected 8 fields, saw 9\nSkipping line 3011313: expected 8 fields, saw 9\nSkipping line 3012146: expected 8 fields, saw 9\nSkipping line 3012252: expected 8 fields, saw 9\n'
# b'Skipping line 3018742: expected 8 fields, saw 9\nSkipping line 3020645: expected 8 fields, saw 9\nSkipping line 3021210: expected 8 fields, saw 9\nSkipping line 3023922: expected 8 fields, saw 9\nSkipping line 3024005: expected 8 fields, saw 9\nSkipping line 3024816: expected 8 fields, saw 9\nSkipping line 3024976: expected 8 fields, saw 9\nSkipping line 3025299: expected 8 fields, saw 9\nSkipping line 3026832: expected 8 fields, saw 9\nSkipping line 3027557: expected 8 fields, saw 9\nSkipping line 3027825: expected 8 fields, saw 9\nSkipping line 3031892: expected 8 fields, saw 9\nSkipping line 3032682: expected 8 fields, saw 9\nSkipping line 3034238: expected 8 fields, saw 9\nSkipping line 3036671: expected 8 fields, saw 9\nSkipping line 3038958: expected 8 fields, saw 9\nSkipping line 3039107: expected 8 fields, saw 9\nSkipping line 3040819: expected 8 fields, saw 9\nSkipping line 3042039: expected 8 fields, saw 9\nSkipping line 3045378: expected 8 fields, saw 9\nSkipping line 3047054: expected 8 fields, saw 9\nSkipping line 3054243: expected 8 fields, saw 9\nSkipping line 3055384: expected 8 fields, saw 9\nSkipping line 3058786: expected 8 fields, saw 9\nSkipping line 3059908: expected 8 fields, saw 9\nSkipping line 3060024: expected 8 fields, saw 9\nSkipping line 3060034: expected 8 fields, saw 9\nSkipping line 3066076: expected 8 fields, saw 9\nSkipping line 3069513: expected 8 fields, saw 10\nSkipping line 3071502: expected 8 fields, saw 9\nSkipping line 3071894: expected 8 fields, saw 9\nSkipping line 3072872: expected 8 fields, saw 9\nSkipping line 3077972: expected 8 fields, saw 9\nSkipping line 3079348: expected 8 fields, saw 9\nSkipping line 3080114: expected 8 fields, saw 9\nSkipping line 3080444: expected 8 fields, saw 9\n'
# b'Skipping line 3303857: expected 8 fields, saw 10\nSkipping line 3317592: expected 8 fields, saw 10\nSkipping line 3318284: expected 8 fields, saw 10\nSkipping line 3331125: expected 8 fields, saw 9\n'

# %%
data.to_excel('Raw_data.xlsx')

# %%
cond = data.loc[(data.product_name!='Ncell Topup') & (data.product_name!='NT Postpaid Topup' )&(data.product_name!='NT Prepaid Topup')]

# %%
data.head()
# Out:
#    payer_account_id created_day  product_id      product_name  amount_sum  \
# 0          265501.0  2018-08-06           7        Send Money     1024.24
# 1          369755.0  2018-08-06         200  NT Prepaid Topup      100.00
# 2          439680.0  2018-08-06         200  NT Prepaid Topup       10.00
# 3          412923.0  2018-08-06          15       Ncell Topup       20.00
# 4          494207.0  2018-08-06         200  NT Prepaid Topup      100.00
#
#    revenue_sum  fullname_X  user_name_X
# 0         0.00      255495     255495.0
# 1         0.80      359354     359354.0
# 2         0.08      429302     429302.0
# 3         0.16      402598     402598.0
# 4         0.80      483671     483671.0

# %%
inp = cond[['fullname_X','product_name']]

# %%
prep = inp.groupby('fullname_X').product_name.apply(list)

# %%
prep.head()
# Out:
# fullname_X
# 13    [Subisu Cablenet , Subisu Cablenet , Siddharth...
# 14    [Nabil Bank Credit Card, Dish Home Topup, Net ...
# 15    [NT Landline Payment, Nepal Electricity Author...
# 22    [Bigmovies, NT Landline Payment, QFX Chhaya Ce...
# 28    [QFX Chhaya Centre, Sim TV, Sim TV, QFX Cinema...
# Name: product_name, dtype: object

# %%
prep = inp.groupby('fullname_X').product_name.apply(set)

# %%
prep.head()
# Out:
# fullname_X
# 13    {Send Money, Siddhartha Bank Credit Card, Nepa...
# 14    {Nabil Bank Credit Card, Net TV, Send Money, D...
# 15    {Nepal Electricity Authority, Send Money, NT L...
# 22    {QFX Cinemas, Bigmovies, NT CDMA Prepaid Topup...
# 28             {QFX Cinemas, Sim TV, QFX Chhaya Centre}
# Name: product_name, dtype: object

# %%
listed = list(prep)

# %%
listed
# Out:
# [{'BUDDHA AIR',
#   'Bhatbhateni Online',
#   'Cash Out',
#   'Epay Donation',
#   'Nepal Electricity Authority',
#   'Send Money',
#   'Siddhartha Bank Credit Card',
#   'Subisu Cablenet '},
#  {'Dish Home Topup', 'Nabil Bank Credit Card', 'Net TV', 'Send Money'},
#  {'NT Landline Payment',
#   'Nepal Electricity Authority',
#   'Send Money',
#   'Sim TV'},
#  {'BSR Movies',
#   'Bigmovies',
#   'NT CDMA Prepaid Topup',
#   'NT Landline Payment',
#   'Oho Domain',
#   'QFX Chhaya Centre',
#   'QFX Cinemas'},
#  {'QFX Chhaya Centre', 'QFX Cinemas', 'Sim TV'},
#  {'BUDDHA AIR',
#   'Dhangadi Premier League 2018',
#   'Dish Home Topup',
#   'NT ADSL Topup - Unlimited',
#   'NT Landline Payment'},
#  {'Epay Donation',
#   'FCube Cinemas',
#   'Global IME Visa Credit Cards',
#   'Inception Collection Center',
#   'NCELL PRO',
#   'NCELL TOPUP',
#   'NT Landline Payment',
#   'Nabil Bank Credit Card',
#   'SHREE AIRLINES',
#   'Send Money',
#   'Sharesansar'},
#  {'BUDDHA AIR',
#   'CAN',
#   'NCELL TOPUP',
#   'Nabil Bank Credit Card',
#   'QFX Cinemas',
#   'Send Money',
#   'WorldLink Pay'},
#  {'QFX Chhaya Centre'},
#  {'YETI AIRLINES'},
#  {'Mero TV', 'Oho Domain', 'Radius Communications'},
#  {'Dish Home Topup',
#   'Nabil Bank Credit Card',
#   'Net TV Recharge Card for Mobile App',
#   'Smart Cell Topup',
#   'WorldLink Pay',
#   'eSewapasal'},
#  {'NCELL TOPUP',
#   'Nabil Bank Credit Card',
#   'Nepal Electricity Authority',
#   'QFX Cinemas',
#   'Send Money'},
#  {'NT ADSL Topup - Unlimited', 'Send Money'},
#  {'BUDDHA AIR',
#   'Bhoj',
#   'Dish Home Topup',
#   'Mero TV',
#   'Nepal Electricity Authority',
#   'QFX Cinemas',
#   'Send Money',
#   'Siddhartha Bank Credit Card',
#   'Tootle',
#   'Vianet',
#   'YETI AIRLINES'},
#  {'Paschim Nepal Bus(pnbbs)',
#   'QFX Cinemas',
#   'Reecharger.com',
#   'WorldLink Pay'},
#  {'WorldLink Pay'},
#  {'WorldLink Pay'},
#  {'Nabil Bank Credit Card',
#   'Oho Domain',
#   "Q's Cinemas",
#   'Send Money',
#   'WorldLink NETTV'},
#  {'NCELL TOPUP', 'Send Money'},
#  {'Epay Donation', "Q's Cinemas", 'SIMRIK AIRLINES', 'Sim TV', 'Vianet'},
#  {'Bhoj',
#   'Bussewa.com',
#   'Nabil Bank Credit Card',
#   'Nepal Electricity Authority',
#   'Pasls.com',
#   'Send Money',
#   'Siddhartha Bank Credit Card',
#   'Tootle',
#   'eSewapasal'},
#  {'QFX Cinemas'},
#  {'Nepal Electricity Authority', 'Send Money', 'Smart Cell Topup', 'Vianet'},
#  {'Net TV', 'QFX Cinemas'},
#  {'Midwest', 'Worldlink'},
#  {'BSR Movies', 'QFX Cinemas', 'Smart Cell Topup', 'WorldLink Pay'},
#  {'QFX Cinemas', 'Vianet', 'WorldLink Pay'},
#  {'NT ADSL Topup - Unlimited', 'NT Landline Payment', 'Send Money'},
#  {'Nepal Electricity Authority'},
#  {'Nepal Electricity Authority'},
#  {'Send Money'},
#  {'Kaspersky Antivirus'},
#  {'QFX Chhaya Centre'},
#  {'NT Landline Payment',
#   'Nepal Electricity Authority',
#   'Send Money',
#   'Subisu Cablenet ',
#   'WorldLink Pay',
#   'Worldlink'},
#  {'Subisu Cablenet '},
#  {'Dish Home Topup',
#   'NT ADSL Topup - Unlimited',
#   'Nepal Electricity Authority'},
#  {'Tootle'},
#  {'Oho Domain', 'Send Money', 'TEACH FOR NEPAL'},
#  {'Bigmovies',
#   'NT Landline Payment',
#   'Send Money',
#   'Subisu Cablenet ',
#   'Vianet',
#   'WorldLink Pay'},
#  {'WorldLink Pay'},
#  {'Vianet'},
#  {'BUDDHA AIR',
#   'Net TV',
#   'Net TV Recharge Card for Mobile App',
#   'Send Money',
#   'WorldLink Pay',
#   'Worldlink'},
#  {'NT ADSL Topup - Unlimited',
#   'NT Landline Payment',
#   'Nepal Electricity Authority',
#   'Vianet'},
#  {'NT Landline Payment'},
#  {'Nepal Electricity Authority', 'Net TV', 'Sim TV'},
#  {'NT Landline Payment',
#   'Nepal Electricity Authority',
#   'Net TV',
#   'Worldlink',
#   'Yeti Airlines'},
#  {'Net TV'},
#  {'NCELL TOPUP'},
#  {'LokSewa Nepal', 'QFX Cinemas', 'Send Money', nan},
#  {'Nepal Electricity Authority'},
#  {'BUDDHA AIR',
#   'NCELL TOPUP',
#   'NT Landline Payment',
#   'Nepal Electricity Authority'},
#  {'Global IME Capital', 'NT Landline Payment'},
#  {'Nepal Electricity Authority',
#   "Q's Cinemas",
#   'QFX Cinemas',
#   'YETI AIRLINES'},
#  {'BUDDHA AIR', 'QFX Cinemas'},
#  {'Dish Home Topup',
#   'Oho Domain',
#   'Siddhartha Bank Credit Card',
#   'WorldLink NETTV'},
#  {'NT ADSL Topup - Unlimited', 'Nepal Electricity Authority', 'WorldLink Pay'},
#  {'Nepal Electricity Authority', 'Sim TV'},
#  {'BUDDHA AIR',
#   'NT Landline Payment',
#   'Nepal Electricity Authority',
#   "Nepal Engineer's Association",
#   'QFX Chhaya Centre',
#   'QFX Cinemas',
#   'Radius Communications',
#   'Send Money',
#   'Subisu Cablenet ',
#   'Vianet'},
#  {'Nabil Bank Credit Card'},
#  {'NT ADSL Topup - Unlimited', 'NT Landline Payment'},
#  {'Dish Home Topup',
#   'Global IME Capital',
#   'QFX Cinemas',
#   'WorldLink Pay',
#   'Worldlink'},
#  {'Dish Home Recharge Card'},
#  {'WorldLink Pay'},
#  {'ADSL Bill Payment',
#   'Dadhikot Khanepani',
#   'Dish Home Topup',
#   'HONS',
#   'Mero TV',
#   'NT ADSL Topup - Unlimited',
#   'NT CDMA Prepaid Topup',
#   'NT Landline Payment',
#   'NT Sim Card*****',
#   'Nepal Electricity Authority',
#   'Send Money',
#   'Smart Cell Topup',
#   'Vianet',
#   'WorldLink Pay'},
#  {'FCube Cinemas', 'NT Landline Payment', 'Nepal Electricity Authority'},
#  {'Nepal Electricity Authority', 'Pragatinagar Khanepani'},
#  {'NT ADSL Topup - Unlimited', 'Net TV'},
#  {'Dish Home Topup',
#   'Nepal Electricity Authority',
#   'Net TV Recharge Card for Mobile App',
#   'QFX Cinemas',
#   'Send Money',
#   'Vianet'},
#  {'NT Landline Payment',
#   'Nepal Electricity Authority',
#   'QFX Cinemas',
#   'Subisu Cablenet '},
#  {'NT Landline Payment', 'Nepal Electricity Authority'},
#  {'Dish Home Recharge Card', 'Net TV', 'Send Money', 'Sim TV', 'Worldlink'},
#  {'BUDDHA AIR',
#   'Dish Home Topup',
#   'Nepal Electricity Authority',
#   'Send Money',
#   'Smart Cell Topup',
#   'Vianet'},
#  {'NT ADSL Topup - Unlimited', 'NT Landline Payment', 'WorldLink Pay'},
#  {'Dish Home Topup', 'NT ADSL Topup - Unlimited'},
#  {'NT ADSL Topup - Unlimited',
#   'NT CDMA Prepaid Topup',
#   'Nepal Electricity Authority',
#   'Net TV',
#   'Reecharger.com'},
#  {'Global IME Capital'},
#  {'Bigmovies',
#   'NT ADSL Topup - Unlimited',
#   'NT Landline Payment',
#   'WorldLink NETTV'},
#  {'Nepal Electricity Authority', 'QFX Cinemas', 'Vianet', 'YETI AIRLINES'},
#  {'Dish Home Topup', 'Vianet'},
#  {'Net TV Recharge Card for Mobile App', 'QFX Cinemas', 'Sim TV', 'Vianet'},
#  {'NT ADSL Topup - Unlimited'},
#  {'NT Landline Payment', 'Send Money'},
#  {'Nepal Electricity Authority', 'WorldLink Pay'},
#  {'NT Landline Payment',
#   'Nepal Electricity Authority',
#   'Send Money',
#   'Sim TV',
#   'Vianet'},
#  {'Nepal Electricity Authority', 'Vianet'},
#  {'Bigmovies',
#   'NT ADSL Topup - Unlimited',
#   'NT Landline Payment',
#   'Nepal Electricity Authority'},
#  {'NT Landline Payment', 'Nepal Electricity Authority'},
#  {'Send Money'},
#  {'Kaspersky Antivirus', 'Nepal Electricity Authority', 'QFX Chhaya Centre'},
#  {'NT CDMA Prepaid Topup', 'NT Landline Payment'},
#  {'Bigmovies', 'Vianet', 'YETI AIRLINES'},
#  {'Dish Home Recharge Card',
#   'NT Landline Payment',
#   'Net TV',
#   "Q's Cinemas",
#   'QFX Cinemas',
#   'Send Money',
#   'Vianet'},
#  {'NT ADSL Topup - Volume Based', 'NT CDMA Prepaid Topup', 'Send Money'},
#  {'NT Landline Payment', 'QFX Jalma Bharatpur', 'Send Money'},
#  {'NT CDMA Prepaid Topup', 'Nepal Electricity Authority', 'Net TV'},
#  {'NT Landline Payment',
#   'QFX Cinemas',
#   'Send Money',
#   'Siddhartha Bank Credit Card',
#   'Subisu Cablenet '},
#  {'Dish Home Recharge Card', 'Dish Home Topup', 'NT Landline Payment'},
#  {'Nepal Electricity Authority',
#   'Net TV',
#   'QFX Cinemas',
#   'Send Money',
#   'Worldlink'},
#  {'Yeti Airlines'},
#  {'BUDDHA AIR',
#   'NT ADSL Topup - Unlimited',
#   'NT ADSL Topup - Volume Based',
#   'NT Landline Payment',
#   'Nepal Electricity Authority',
#   'Reecharger.com',
#   'Send Money',
#   'YETI AIRLINES'},
#  {'Dish Home Topup',
#   'NT Recharge Card',
#   'Nepal Electricity Authority',
#   'QFX Cinemas',
#   'Subisu Cablenet ',
#   'Tootle'},
#  {'BSR Movies', 'Vianet'},
#  {'BUDDHA AIR',
#   'NEPAL MEDICAL COUNCIL - TOKEN',
#   'QFX Chhaya Centre',
#   'QFX Cinemas',
#   'Send Money',
#   'Tootle',
#   'WorldLink NETTV',
#   'YETI AIRLINES'},
#  {'NT Landline Payment', 'Nepal Electricity Authority'},
#  {'Net TV', 'Send Money'},
#  {'NCELL TOPUP', 'QFX Cinemas'},
#  {'NT Landline Payment', 'Nepal Electricity Authority', 'Vianet'},
#  {'Broadlink Recharge Card',
#   'Classic Tech Pvt. Ltd.',
#   'Dish Home Topup',
#   'NT Landline Payment',
#   'Reecharger.com',
#   'Send Money'},
#  {'BSR Movies'},
#  {'Dish Home Topup', 'Nepal Electricity Authority', 'YETI AIRLINES'},
#  {'Dish Home Topup'},
#  {'NT ADSL Topup - Unlimited', 'NT Landline Payment'},
#  {'NT ADSL Topup - Unlimited'},
#  {'Inception Collection Center',
#   'Oho Domain',
#   'QFX Cinemas',
#   'Sanima Bank Credit Card',
#   'WorldLink Pay',
#   'eSewapasal'},
#  {'Dish Home Topup'},
#  {'Epay Donation', 'Radius Communications'},
#  {'NT Landline Payment', 'NT Recharge Card', 'Sim TV'},
#  {'BUDDHA AIR', 'Oho Domain', 'QFX Cinemas'},
#  {'Worldlink'},
#  {'Dish Home Topup',
#   'Mytrip2nepal.com',
#   'QFX Cinemas',
#   'SHREE AIRLINES',
#   'Send Money'},
#  {'Dish Home Topup',
#   'HONS',
#   'Mero TV',
#   'NAMS-TOKEN',
#   'NT ADSL Topup - Unlimited',
#   'NT CDMA Postpaid Topup',
#   'NT CDMA Prepaid Topup',
#   'NT Landline Payment',
#   'Nepal Electricity Authority',
#   'Send Money',
#   'Sim TV',
#   'Smart Cell Recharge Card',
#   'Smart Cell Topup',
#   'Subisu Cablenet ',
#   'Vianet',
#   'WorldLink Pay'},
#  {'NCELL PRO'},
#  {'BUDDHA AIR',
#   'Broadlink Recharge Card',
#   'Oho Domain',
#   'Send Money',
#   'WorldLink NETTV'},
#  {'Bigmovies',
#   'Bussewa.com',
#   'NT Landline Payment',
#   'Nepal Electricity Authority',
#   'Send Money',
#   'WorldLink NETTV',
#   'YETI AIRLINES'},
#  {'BUDDHA AIR',
#   'Mero TV',
#   'NT Landline Payment',
#   'Nabil Bank Credit Card',
#   'Nepal Electricity Authority',
#   'QFX Cinemas',
#   'Reecharger.com',
#   'Tootle',
#   'WorldLink Pay',
#   'YETI AIRLINES',
#   'eSewapasal'},
#  {'WorldLink NETTV'},
#  {'Paschim Nepal Bus(pnbbs)'},
#  {'BUDDHA AIR',
#   'FCube Cinemas',
#   'NCELL PRO',
#   'NCELL TOPUP',
#   'NT ADSL Topup - Unlimited',
#   'Nepal Electricity Authority',
#   'QFX Cinemas',
#   'Send Money',
#   'Sharesansar',
#   'Vianet',
#   'WorldLink Pay',
#   'YETI AIRLINES'},
#  {'Send Money'},
#  {'Send Money'},
#  {'Nepal Electricity Authority', 'Net TV'},
#  {'BSR Movies',
#   'BUDDHA AIR',
#   'Bigmovies',
#   'NCELL TOPUP',
#   'Net TV',
#   "Q's Cinemas",
#   'SHREE AIRLINES',
#   'SIMRIK AIRLINES',
#   'Send Money',
#   'Vianet',
#   'YETI AIRLINES'},
#  {'Nepal Electricity Authority', 'Send Money', 'Sim TV', 'Vianet'},
#  {'WorldLink Pay'},
#  {'Epay Donation',
#   'NT ADSL Topup - Unlimited',
#   'NT Landline Payment',
#   'Nepal Electricity Authority',
#   'Net TV',
#   'QFX Cinemas',
#   'SHREE AIRLINES',
#   'Send Money',
#   'Subisu Cablenet ',
#   'Vianet',
#   'WorldLink Pay'},
#  {'Send Money', 'UTL Recharge Card'},
#  {'WorldLink Pay'},
#  {'Vianet'},
#  {'Nepal Electricity Authority', 'Send Money', 'Subisu Cablenet '},
#  {'Classic Tech Pvt. Ltd.',
#   'NT Landline Payment',
#   'Nepal Electricity Authority',
#   'Send Money'},
#  {'Dish Home Topup', 'Smart Cell Topup'},
#  {'BSR Movies',
#   'Bigmovies',
#   'QFX Chhaya Centre',
#   'Send Money',
#   'Subisu Cablenet '},
#  {'Dish Home Topup'},
#  {'BUDDHA AIR',
#   'Dish Home Recharge Card',
#   'Dish Home Topup',
#   'Nepal Electricity Authority',
#   'SHREE AIRLINES',
#   'Saurya Airlines',
#   'Send Money'},
#  {'Dish Home Topup', 'Send Money'},
#  {'Nepal Electricity Authority', 'Send Money', 'WorldLink Pay'},
#  {'NT Landline Payment', 'Nepal Electricity Authority', 'Vianet'},
#  {'Dish Home Recharge Card',
#   'Dish Home Topup',
#   'NT Landline Payment',
#   'NT Recharge Card',
#   'Nepal Electricity Authority'},
#  {'Dish Home Topup',
#   'QFX Chhaya Centre',
#   'QFX Cinemas',
#   'SHREE AIRLINES',
#   'Send Money',
#   'WorldLink NETTV',
#   'Worldlink'},
#  {'WorldLink Pay'},
#  {'Namaste Kapilvastu', 'Oho Domain', 'Send Money'},
#  {'BUDDHA AIR',
#   'Dish Home Topup',
#   'SHREE AIRLINES',
#   'Send Money',
#   'YETI AIRLINES'},
#  {'BUDDHA AIR',
#   'Nepal Electricity Authority',
#   "Q's Cinemas",
#   'SHREE AIRLINES',
#   'Send Money',
#   'YETI AIRLINES'},
#  {'Dish Home Topup',
#   'NCELL TOPUP',
#   'Nepal Electricity Authority',
#   'Send Money',
#   'WorldLink Pay'},
#  {'Itahari Khanepani', 'Nepal Electricity Authority', 'Radius Communications'},
#  {'Epay Donation',
#   'Nepal Electricity Authority',
#   'Oho Domain',
#   'Reecharger.com',
#   'Send Money',
#   'Vianet',
#   nan},
#  {'NT ADSL Topup - Unlimited',
#   'QFX Cinemas',
#   'Smart Cell Recharge Card',
#   'Smart Cell Topup'},
#  {'Dish Home Topup',
#   'NT ADSL Topup - Unlimited',
#   'NT Recharge Card',
#   'Oho Domain',
#   'QFX Cinemas'},
#  {'QFX Cinemas'},
#  {'Nepal Electricity Authority', 'Send Money', 'Subisu Cablenet '},
#  {'Bigmovies',
#   'NT Landline Payment',
#   'Nepal Electricity Authority',
#   "Q's Cinemas"},
#  {'Inception Collection Center',
#   'Nepal Electricity Authority',
#   'WorldLink NETTV'},
#  {'BSR Movies',
#   'FCube Cinemas',
#   'NT ADSL Topup - Unlimited',
#   'NT CDMA Prepaid Topup',
#   'NT Landline Payment',
#   'Net TV Recharge Card for Mobile App',
#   "Q's Cinemas",
#   'QFX Chhaya Centre',
#   'Send Money'},
#  {'Bigmovies'},
#  {'WorldLink Pay'},
#  {'Bigmovies',
#   'Bussewa.com',
#   'NT Landline Payment',
#   "Q's Cinemas",
#   'Send Money'},
#  {'NT ADSL Topup - Unlimited', 'NT Landline Payment', 'Reecharger.com'},
#  {'Dish Home Topup',
#   'NT Landline Payment',
#   'Nepal Electricity Authority',
#   'ONLINEKINMEL.COM',
#   'SHREE AIRLINES'},
#  {'NT Landline Payment',
#   'Nepal Electricity Authority',
#   'Send Money',
#   'Worldlink',
#   nan},
#  {'NT CDMA Prepaid Topup',
#   'NT Landline Payment',
#   'Nepal Electricity Authority',
#   'Send Money'},
#  {'Nepal Electricity Authority'},
#  {'NT Landline Payment', 'Nepal Electricity Authority', 'Smart Cell Topup'},
#  {'Bigmovies',
#   "Q's Cinemas",
#   'QFX Chhaya Centre',
#   'QFX Cinemas',
#   'Send Money'},
#  {'BSR Movies',
#   'NT Landline Payment',
#   'Nepal Electricity Authority',
#   'QFX Cinemas'},
#  {'NT ADSL Topup - Unlimited',
#   'NT Landline Payment',
#   'Nepal Electricity Authority',
#   'Net TV',
#   'Net TV Recharge Card for Mobile App',
#   'WorldLink NETTV',
#   'WorldLink Pay'},
#  {'Bigmovies',
#   'Net TV',
#   'Net TV Recharge Card for Mobile App',
#   'Send Money',
#   'Subisu Cablenet '},
#  {'Bigmovies', 'Send Money'},
#  {'NT ADSL Topup - Volume Based',
#   'NT Landline Payment',
#   'Nepal Electricity Authority',
#   'Smart Cell Topup',
#   'WorldLink Pay'},
#  {'Nepal Electricity Authority'},
#  {'Bigmovies',
#   'Classic Tech Pvt. Ltd.',
#   'Dish Home Topup',
#   'FCube Cinemas',
#   'Kaspersky Antivirus',
#   'NT Landline Payment',
#   'Nepal Electricity Authority',
#   'Subisu Cablenet '},
#  {'NT Landline Payment', 'Nepal Electricity Authority'},
#  {'BUDDHA AIR', 'Nepal Electricity Authority', 'WorldLink NETTV'},
#  {'NT Landline Payment', 'Nepal Electricity Authority', 'Send Money'},
#  {'NT ADSL Topup - Unlimited', 'NT Landline Payment', 'Send Money'},
#  {'Merojob', 'Send Money', 'WorldLink Pay'},
#  {'BUDDHA AIR',
#   'NT Recharge Card',
#   'Nepal Electricity Authority',
#   'Net TV Recharge Card for Mobile App',
#   'Sim TV',
#   'Vianet',
#   'WorldLink Pay'},
#  {'BUDDHA AIR',
#   'Epay Donation',
#   'NCELL TOPUP',
#   'Nepal Electricity Authority',
#   "Q's Cinemas",
#   'Radius Communications',
#   'Send Money',
#   'WorldLink Pay'},
#  {'Mero TV',
#   'NT Landline Payment',
#   'Nepal Electricity Authority',
#   'QFX Cinemas',
#   'Smart Cell Topup',
#   'Yeti Airlines'},
#  {'QFX Cinemas', 'Saurya Airlines', 'Send Money', 'YETI AIRLINES'},
#  {'BUDDHA AIR',
#   'Epay Donation',
#   'NT Landline Payment',
#   'Nabil Bank Credit Card',
#   'Nepal Electricity Authority',
#   'Radius Communications',
#   'WorldLink NETTV',
#   'WorldLink Pay',
#   'YETI AIRLINES'},
#  {'NT CDMA Prepaid Topup'},
#  {'Nepal Electricity Authority', 'Oho Domain', 'QFX Chhaya Centre'},
#  {'NT ADSL Topup - Unlimited',
#   'NT Landline Payment',
#   'QFX Cinemas',
#   'Sim TV',
#   'Travel Nepal Bus Service',
#   'Vianet'},
#  {'Net TV Recharge Card for Mobile App', 'QFX Cinemas', 'Tootle'},
#  {'Nabil Bank Credit Card', 'Net TV'},
#  {'Bigmovies', 'Dish Home Topup', 'Send Money'},
#  {'Bigmovies', 'Classic Tech Pvt. Ltd.', 'Net TV'},
#  {'NT Landline Payment', 'Vianet', 'WorldLink NETTV'},
#  {'Send Money'},
#  {'NCELL TOPUP', 'Subisu Cablenet '},
#  {'Nepal Electricity Authority', 'Smart Cell Recharge Card'},
#  {'Dish Home Topup',
#   'NT ADSL Topup - Unlimited',
#   'NT Landline Payment',
#   'Subisu Cablenet '},
#  {'Dish Home Topup',
#   'Nepal Electricity Authority',
#   'Net TV',
#   'Net TV Recharge Card for Mobile App',
#   'Vianet'},
#  {'WorldLink Pay'},
#  {'Send Money', 'eSewapasal'},
#  {'BSR Movies', 'Sim TV'},
#  {'Dish Home Topup',
#   'Nepal Electricity Authority',
#   'Sastodeal.com',
#   'Send Money'},
#  {'NT ADSL Topup - Unlimited', 'Send Money'},
#  {'Dish Home Topup', 'Net TV', 'Oho Domain', 'Send Money', 'Subisu Cablenet '},
#  {'NT Landline Payment', 'Send Money', 'WorldLink Pay'},
#  {'BSR Movies',
#   'Dish Home Topup',
#   'Epay Donation',
#   'FCube Cinemas',
#   'NCELL TOPUP',
#   'NT ADSL Topup - Unlimited',
#   'QFX Chhaya Centre',
#   'QFX Cinemas',
#   'Send Money',
#   'WorldLink Pay',
#   'YETI AIRLINES'},
#  {'Dish Home Topup',
#   'NT CDMA Postpaid Topup',
#   'QFX Chhaya Centre',
#   'QFX Cinemas',
#   'Send Money',
#   'Vianet'},
#  {'Merojob',
#   'NT Landline Payment',
#   'Nepal Electricity Authority',
#   'Oho Domain',
#   'QFX Chhaya Centre',
#   'QFX Cinemas',
#   'Sharesansar',
#   'Tootle',
#   'Vianet',
#   'WorldLink Pay',
#   'Worldlink'},
#  {'Tootle'},
#  {'Itahari Khanepani',
#   'NT Landline Payment',
#   'Nepal Electricity Authority',
#   'Send Money'},
#  {'Nabil Bank Credit Card', 'SHREE AIRLINES', 'Subisu Cablenet '},
#  {'BUDDHA AIR',
#   'Nepal Electricity Authority',
#   'SHREE AIRLINES',
#   'Send Money',
#   'Subisu Cablenet ',
#   'YETI AIRLINES'},
#  {'Epay Donation',
#   'NT ADSL Topup - Unlimited',
#   'Nepal Electricity Authority',
#   'SHREE AIRLINES',
#   'Smart Cell Topup',
#   'Subisu Cablenet '},
#  {'Dish Home Topup',
#   'NT Landline Payment',
#   'QFX Cinemas',
#   'WorldLink Pay',
#   'Worldlink',
#   'YETI AIRLINES'},
#  {'Merojob', 'QFX Cinemas', 'Sim TV', 'Vianet', 'WorldLink Pay'},
#  {'Send Money'},
#  {'Merolagani.com',
#   'NT Landline Payment',
#   'Nepal Electricity Authority',
#   'QFX Cinemas',
#   'WorldLink Pay',
#   'Worldlink'},
#  {'BUDDHA AIR', 'NT CDMA Prepaid Topup', 'WorldLink Pay'},
#  {'Dish Home Topup',
#   'NT Landline Payment',
#   'Nepal Electricity Authority',
#   'QFX Cinemas',
#   'Send Money',
#   'Vianet',
#   'WorldLink Pay',
#   'Worldlink'},
#  {'Dish Home Topup',
#   'NT ADSL Topup - Unlimited',
#   'Net TV',
#   'Send Money',
#   'WorldLink Pay'},
#  {'BUDDHA AIR',
#   'NCELL PRO',
#   'Radius Communications',
#   'Send Money',
#   'YETI AIRLINES'},
#  {'Vianet', 'WorldLink Pay'},
#  {'Bigmovies', 'Send Money'},
#  {'Dish Home Recharge Card',
#   'Dish Home Topup',
#   'NT Landline Payment',
#   'Nepal Electricity Authority',
#   'Send Money',
#   'WorldLink Pay'},
#  {'Send Money'},
#  {'NT ADSL Topup - Unlimited',
#   'NT CDMA Prepaid Topup',
#   'Smart Cell Topup',
#   'Tootle'},
#  {"Q's Cinemas", 'QFX Cinemas', 'Send Money'},
#  {'Bigmovies',
#   'International Airlines',
#   "Q's Cinemas",
#   'QFX Cinemas',
#   'SHREE AIRLINES',
#   'Saurya Airlines',
#   'Send Money',
#   'YETI AIRLINES',
#   'Yeti Airlines'},
#  {'BUDDHA AIR',
#   'Hamro Doctor',
#   'LokSewa Nepal',
#   'Send Money',
#   'Vianet',
#   'YETI AIRLINES'},
#  {'BUDDHA AIR'},
#  {'Bhoj',
#   'Nabil Bank Credit Card',
#   'QFX Chhaya Centre',
#   'QFX Cinemas',
#   'Tootle'},
#  {'Nepal Electricity Authority', 'Send Money'},
#  {'NT Landline Payment',
#   'Nepal Electricity Authority',
#   'Vianet',
#   'eSewapasal'},
#  {'Dish Home Topup',
#   'NT Landline Payment',
#   'Nepal Electricity Authority',
#   'Send Money'},
#  {'Bigmovies', 'NT Landline Payment'},
#  {'Buddha Air Agent Balance Topup',
#   'NT Landline Payment',
#   'Nabil Bank Credit Card',
#   'Vidhya Sanskar School',
#   'WorldLink Pay'},
#  {'Dish Home Topup',
#   'NAMS-online payment',
#   'NT Landline Payment',
#   'Nabil Bank Credit Card',
#   'Net TV'},
#  {'Buymandu.com',
#   'NT Landline Payment',
#   'Nepal Electricity Authority',
#   'Send Money',
#   'Subisu Cablenet '},
#  {'NT ADSL Topup - Unlimited',
#   'NT Landline Payment',
#   'Nepal Electricity Authority',
#   'Send Money',
#   'Vianet'},
#  {'BUDDHA AIR',
#   'CAN',
#   'Dish Home Topup',
#   'HCC Segregate Account',
#   'Nepal Electricity Authority',
#   'QFX  Cineplex Pokhara',
#   'QFX Cinemas',
#   'Send Money',
#   'Vianet',
#   'YETI AIRLINES'},
#  {'Net TV', 'QFX Cinemas', 'Smart Cell Topup'},
#  {'NT Landline Payment', 'Nepal Electricity Authority', 'WorldLink Pay'},
#  {'Send Money'},
#  {'NT ADSL Topup - Unlimited',
#   'NT Landline Payment',
#   'Nepal Electricity Authority'},
#  {'NT Recharge Card', 'Radius Communications', 'WorldLink Pay'},
#  {'WorldLink NETTV', 'YETI AIRLINES'},
#  {'Dish Home Topup',
#   'Mero TV Mobile Payment',
#   'NT ADSL Topup - Unlimited',
#   'NT Landline Payment',
#   'Net TV',
#   'ONLINEKINMEL.COM',
#   'QFX Cinemas',
#   'Send Money',
#   'Shree Airlines B2C'},
#  {'NT Landline Payment', 'Send Money', 'Vianet'},
#  {'Epay Donation',
#   'NT ADSL Topup - Unlimited',
#   'NT CDMA',
#   'NT CDMA Prepaid Topup',
#   'Nepal Electricity Authority',
#   'Sharesansar'},
#  {'BUDDHA AIR',
#   'Global IME Capital',
#   'International Airlines',
#   'NT Landline Payment',
#   'Nepal Electricity Authority'},
#  {'Send Money', 'Tootle', 'UTL Recharge Card'},
#  {'Dish Home Topup',
#   'NT ADSL Topup - Unlimited',
#   'NT Landline Payment',
#   'Nepal Electricity Authority',
#   'Smart Cell Topup'},
#  {'BUDDHA AIR',
#   'NT Landline Payment',
#   'Nepal Electricity Authority',
#   'QFX Cinemas',
#   'Vianet',
#   'YETI AIRLINES'},
#  {'Nepal Electricity Authority', 'QFX Cinemas'},
#  {'BUDDHA AIR',
#   'Dish Home Topup',
#   'Global IME Capital',
#   'NT Landline Payment',
#   'NT Recharge Card',
#   'QFX Chhaya Centre'},
#  {'NT Landline Payment',
#   'Nepal Electricity Authority',
#   'Send Money',
#   'WorldLink Pay'},
#  {'Giftmandu.com', 'YETI AIRLINES'},
#  {'NT Landline Payment', 'Vianet', 'WorldLink Pay'},
#  {'BUDDHA AIR', 'SHREE AIRLINES'},
#  {'NT ADSL Topup - Unlimited', 'Net TV', "Q's Cinemas", 'Sim TV'},
#  {'Smart Cell Topup', 'Vianet'},
#  {'Nepal Electricity Authority', 'QFX Cinemas', 'Vianet'},
#  {'NT Landline Payment', 'WorldLink Pay', 'Worldlink'},
#  {'Dish Home Recharge Card',
#   'Dish Home Topup',
#   'HONS',
#   'Inception Collection Center',
#   'Itel Communication ',
#   'Mero TV',
#   'NT ADSL Topup - Unlimited',
#   'NT CDMA Prepaid Topup',
#   'NT Landline Payment',
#   'Nepal Electricity Authority',
#   'QFX Cinemas',
#   'Send Money',
#   'Sim TV',
#   'Smart Cell Recharge Card',
#   'Smart Cell Topup',
#   'Subisu Cablenet ',
#   'Vianet',
#   'WorldLink Pay'},
#  {'QFX Cinemas'},
#  {'NT Landline Payment',
#   'Nepal Electricity Authority',
#   'Radius Communications',
#   'Send Money',
#   'Vianet',
#   'WorldLink Pay'},
#  {'QFX Cinemas'},
#  {'NT ADSL Topup - Unlimited',
#   'NT Landline Payment',
#   'Nepal Electricity Authority'},
#  {'Nepal Electricity Authority', 'Subisu Cablenet ', 'Vianet'},
#  {'NCELL PRO', 'NCELL TOPUP', 'Reecharger.com', 'Sim TV'},
#  {'BSR Movies',
#   'Dish Home Topup',
#   'International Airlines',
#   'Mero TV',
#   'Merolagani.com',
#   'NT ADSL Topup - Unlimited',
#   'NT ADSL Topup - Volume Based',
#   'NT Landline Payment',
#   'Nepal Electricity Authority',
#   'Send Money'},
#  {'Dish Home Topup', 'Mytrip2nepal.com'},
#  {'Dish Home Topup', 'QFX Cinemas', 'Send Money', 'Vianet'},
#  {'Mero TV',
#   'NT ADSL Topup - Unlimited',
#   'NT Landline Payment',
#   'NT Recharge Card',
#   'Nepal Electricity Authority',
#   'Vianet'},
#  {'BUDDHA AIR',
#   'Dish Home Topup',
#   'QFX Cinemas',
#   'Saurya Airlines',
#   'YETI AIRLINES'},
#  {'NT Recharge Card', 'Send Money'},
#  {'NT Landline Payment',
#   'Nabil Bank Credit Card',
#   'Nepal Electricity Authority',
#   'ONLINEKINMEL.COM',
#   "Q's Cinemas",
#   'QFX Chhaya Centre',
#   'QFX Cinemas',
#   'Subisu Cablenet '},
#  {'Send Money'},
#  {'Dish Home Topup',
#   'NCELL TOPUP',
#   'Prabhu Bank Credit Card ',
#   'Send Money',
#   'Sharesansar',
#   'YETI AIRLINES'},
#  {'Dish Home Topup',
#   'Inception Collection Center',
#   'NT Landline Payment',
#   'Smart Cell Topup',
#   'Subisu Cablenet ',
#   'Vianet'},
#  {'Dish Home Topup',
#   'Nepal Electricity Authority',
#   'QFX Cinemas',
#   'Send Money'},
#  {'BUDDHA AIR',
#   'Oho Domain',
#   'Send Money',
#   'Smart Cell Topup',
#   'YETI AIRLINES'},
#  {'Dish Home Topup',
#   'NT Landline Payment',
#   'NT Recharge Card',
#   'Nepal Electricity Authority',
#   "Q's Cinemas",
#   'Send Money',
#   'WorldLink Pay',
#   'Worldlink'},
#  {'NT CDMA Prepaid Topup', 'Nepal Electricity Authority', 'Send Money'},
#  {'Dish Home Topup',
#   'NT Landline Payment',
#   'Nepal Electricity Authority',
#   'QFX  Cineplex Pokhara',
#   'Reecharger.com'},
#  {'Sim TV'},
#  {'Dish Home Topup', 'Nepal Electricity Authority', 'Vianet'},
#  {'Bigmovies', 'Itel Communication ', 'Nepal Electricity Authority', 'Sim TV'},
#  {'Cash Out',
#   'NCELL TOPUP',
#   'Net TV',
#   'Send Money',
#   'WorldLink NETTV',
#   'WorldLink Pay'},
#  {'Dish Home Topup',
#   'NT Landline Payment',
#   'NT Recharge Card',
#   'QFX Cinemas',
#   'WorldLink Pay'},
#  {'Dish Home Topup',
#   'Nepal Electricity Authority',
#   'Net TV',
#   "Q's Cinemas",
#   'QFX Cinemas',
#   'Send Money',
#   'Tootle',
#   'Vianet'},
#  {'BUDDHA AIR', 'Saurya Airlines'},
#  {'NIC Asia Bank Credit Card', 'YETI AIRLINES'},
#  {'BUDDHA AIR',
#   'Dish Home Topup',
#   'NEPAL NURSING COUNCIL - LICENSE EXAM',
#   'NT ADSL Topup - Unlimited',
#   'NT Landline Payment',
#   'SIMRIK AIRLINES',
#   'Send Money',
#   'Smart Cell Topup',
#   'YETI AIRLINES'},
#  {'FCube Cinemas', 'NT ADSL Topup - Unlimited', 'NT Recharge Card'},
#  {'Dish Home Topup',
#   'FCube Cinemas',
#   'NT Landline Payment',
#   'Nepal Electricity Authority',
#   'Send Money',
#   'Vianet'},
#  {'Nepal Electricity Authority',
#   'QFX Chhaya Centre',
#   'QFX Cinemas',
#   'Send Money',
#   'Vianet'},
#  {'NMB Bank Visa Credit Card'},
#  {'FCube Cinemas'},
#  {'Dish Home Topup', 'Send Money', 'WorldLink Pay'},
#  {'BUDDHA AIR',
#   'NT ADSL Topup - Unlimited',
#   'NT Landline Payment',
#   'Nepal Electricity Authority',
#   'QFX  Cineplex Pokhara',
#   'SHREE AIRLINES',
#   'Send Money'},
#  {'Nepal Electricity Authority'},
#  {'Kaspersky Antivirus',
#   'NT Landline Payment',
#   'Nepal Electricity Authority',
#   'QFX Cinemas',
#   'Send Money',
#   'Smart Cell Topup',
#   'Subisu Cablenet '},
#  {'BUDDHA AIR', 'NT CDMA Prepaid Topup'},
#  {'QFX Cinemas', 'Send Money'},
#  {'BUDDHA AIR',
#   'QFX Cinemas',
#   'SHREE AIRLINES',
#   'Subisu Cablenet ',
#   'YETI AIRLINES'},
#  {'QFX Cinemas', 'Subisu Cablenet '},
#  {'BUDDHA AIR',
#   'Nepal Electricity Authority',
#   'Send Money',
#   'Websurfer.com',
#   nan},
#  {'QFX Chhaya Centre'},
#  {'Dish Home Topup',
#   'NT CDMA Prepaid Topup',
#   'Oho Domain',
#   'Send Money',
#   'YETI AIRLINES'},
#  {"Q's Cinemas"},
#  {'Dish Home Topup',
#   'NT Landline Payment',
#   'Nepal Electricity Authority',
#   'QFX Cinemas',
#   'Send Money',
#   'WorldLink Pay'},
#  {'Nepal Electricity Authority'},
#  {'Global IME Visa Credit Cards', 'Radius Communications', 'YETI AIRLINES'},
#  {'Dish Home Topup',
#   'NT Landline Payment',
#   'Nepal Electricity Authority',
#   'Send Money'},
#  {'Nepal Electricity Authority', 'Send Money'},
#  {'NT ADSL Topup - Unlimited', 'Nepal Electricity Authority', 'Send Money'},
#  {'BUDDHA AIR',
#   'Buddha Air',
#   'CAN',
#   'Dish Home Topup',
#   'Inception Collection Center',
#   'Nepal Electricity Authority',
#   'QFX Cinemas',
#   'Reecharger',
#   'Sharesansar',
#   'Vianet',
#   'Worldlink',
#   'YETI AIRLINES',
#   'eSewapasal',
#   nan},
#  {'NT Landline Payment', 'Nepal Electricity Authority', 'Sim TV'},
#  {'NT ADSL Topup - Unlimited',
#   'NT ADSL Topup - Volume Based',
#   'Nepal Electricity Authority',
#   'Net TV',
#   'Smart Cell Topup'},
#  {'BUDDHA AIR', 'Dish Home Topup', 'Send Money', 'Sim TV'},
#  {'NT Recharge Card', 'Nepal Electricity Authority'},
#  {'Nepal Electricity Authority', 'QFX Cinemas', 'Tootle'},
#  {'Nepal Electricity Authority',
#   'Prabhu Bank Credit Card ',
#   'QFX Chhaya Centre',
#   'QFX Cinemas',
#   'Send Money'},
#  {'Send Money', 'Smart Cell Topup', 'Tootle', 'WorldLink Pay'},
#  {'Vianet'},
#  {'NT CDMA Postpaid Topup', 'Nepal Electricity Authority', 'Vianet'},
#  {'Dish Home Topup', 'Sharesansar', 'Vianet'},
#  {'NT Landline Payment',
#   'Nepal Electricity Authority',
#   'Net TV',
#   'Subisu Cablenet ',
#   'Vianet'},
#  {'Nepal Electricity Authority', 'WorldLink Pay', 'Worldlink'},
#  {'CAN', 'Dish Home Topup', 'NAMS-TOKEN', 'NT Landline Payment'},
#  {'Send Money'},
#  {'BUDDHA AIR',
#   'Dish Home Topup',
#   'NCELL PRO',
#   'NT CDMA Prepaid Topup',
#   'NT Landline Payment',
#   'Nepal Electricity Authority',
#   'Net TV',
#   'Smart Cell Topup',
#   'WorldLink Pay',
#   'Worldlink'},
#  {'NT Landline Payment',
#   'NT Recharge Card',
#   'Nepal Electricity Authority',
#   'Net TV Recharge Card for Mobile App',
#   'Subisu Cablenet ',
#   'WorldLink NETTV',
#   'WorldLink Pay',
#   'Worldlink'},
#  {'Mero TV', 'Merolagani.com', 'Nepal Electricity Authority', 'Send Money'},
#  {'NT Landline Payment',
#   'Nepal Electricity Authority',
#   'Send Money',
#   'YETI AIRLINES'},
#  {'Nepali Paisa', 'QFX Cinemas', 'Vianet'},
#  {'NT Landline Payment', 'Nabil Bank Credit Card'},
#  {'BUDDHA AIR',
#   'Buddha Air',
#   'Dish Home Recharge Card',
#   'Dish Home Topup',
#   'Nepal Electricity Authority',
#   'Net TV',
#   'Oho Domain',
#   'QFX Cinemas'},
#  {'Tootle'},
#  {'QFX Chhaya Centre', 'Radius Communications', 'Worldlink'},
#  {'NT ADSL Topup - Unlimited'},
#  {'Send Money'},
#  {'Smart Cell Topup'},
#  {'Nabil Bank Credit Card'},
#  {'Nabil Bank Credit Card',
#   'Net TV',
#   'Net TV Recharge Card for Mobile App',
#   'QFX Chhaya Centre',
#   'Send Money',
#   'Tootle',
#   'Vianet'},
#  {'A2zOnlineSewa Pvt. Ltd.',
#   'Dish Home Topup',
#   'Epay Donation',
#   'Global IME Capital',
#   'Nepal Electricity Authority',
#   'Send Money',
#   'Subisu Cablenet ',
#   'Vianet'},
#  {'Bigmovies',
#   'NT Landline Payment',
#   'Nepal Electricity Authority',
#   'QFX Cinemas',
#   'Sharesansar',
#   'Subisu Cablenet '},
#  {'NT ADSL Topup - Unlimited', 'Send Money', 'Vianet'},
#  {'FCube Cinemas', 'Reecharger.com', 'Send Money'},
#  {'Merolagani.com'},
#  {'Send Money', 'WorldLink Pay'},
#  {'International Airlines',
#   'Merolagani.com',
#   'Midwest Direct Pay',
#   'NCELL TOPUP',
#   'Radius Communications'},
#  {'Nepal Electricity Authority'},
#  {'Bigmovies', 'QFX Cinemas', 'WorldLink Pay'},
#  {'Global IME Visa Credit Cards',
#   'Nepal Bangladesh Bank Credit Card',
#   'Radius Communications',
#   'Vianet'},
#  {'Classic Tech Pvt. Ltd.', 'NT Recharge Card', 'Nepal Electricity Authority'},
#  {'BUDDHA AIR', 'Bhoj', 'Dish Home Topup', 'Net TV', 'Vianet'},
#  {'BUDDHA AIR', 'Nabil Bank Credit Card'},
#  {'Dish Home Topup', 'Subisu Cablenet ', 'WorldLink Pay'},
#  {'Send Money'},
#  {'NT Landline Payment',
#   'Nepal Electricity Authority',
#   'QFX Cinemas',
#   'Vianet'},
#  {'NT Recharge Card', "Q's Cinemas", 'Subisu Cablenet '},
#  {'NT ADSL Topup - Unlimited',
#   'NT Landline Payment',
#   'SHREE AIRLINES',
#   'SIMRIK AIRLINES',
#   'Worldlink'},
#  {'Bhatbhateni Online',
#   'Dish Home Recharge Card',
#   'International Airlines',
#   'NT Landline Payment',
#   'Oho Domain',
#   'QFX Cinemas',
#   'Send Money',
#   'Siddhartha Bank Credit Card',
#   'eSewapasal'},
#  {'Dish Home Topup',
#   'NT ADSL Topup - Volume Based',
#   'NT Landline Payment',
#   'Nepal Electricity Authority',
#   'Sim TV',
#   'WorldLink Pay'},
#  {'Bigmovies', 'Saurya Airlines'},
#  {"Q's Cinemas", 'WorldLink NETTV'},
#  {'Nepal Electricity Authority'},
#  {'Nepal Electricity Authority', 'Send Money'},
#  {'Dish Home Recharge Card', 'Dish Home Topup', 'Websurfer.com'},
#  {'Itel Communication ', 'NT Landline Payment', 'Nepal Electricity Authority'},
#  {'NT ADSL Topup - Unlimited', 'NT Landline Payment', 'Net TV'},
#  {'Send Money', 'WorldLink Pay'},
#  {'Send Money'},
#  {'Nabil Bank Credit Card', 'Send Money', 'Worldlink'},
#  {'Bussewa.com', 'Net TV', 'Send Money', 'Vianet'},
#  {'Dish Home Topup',
#   'Epay Donation',
#   'NT Landline Payment',
#   'Net TV',
#   'Radius Communications',
#   'Send Money',
#   'WorldLink Pay',
#   'Worldlink'},
#  {'Dish Home Topup',
#   'NT ADSL Topup - Unlimited',
#   'NT Landline Payment',
#   'Nepal Electricity Authority',
#   'Smart Cell Topup',
#   'Subisu Cablenet '},
#  {'Buymandu.com',
#   'Epay Donation',
#   'Inception Collection Center',
#   'Nabil Bank Credit Card',
#   'Nepal Electricity Authority',
#   'Net TV',
#   'Oho Domain',
#   'Send Money',
#   'Vianet',
#   'Worldlink',
#   nan},
#  {'NT Landline Payment',
#   'Nepal Electricity Authority',
#   'Net TV Recharge Card for Mobile App',
#   'Premier Insurance ',
#   'Send Money',
#   'WorldLink Pay',
#   'YETI AIRLINES'},
#  {'NT ADSL Topup - Unlimited'},
#  {'Inception Collection Center'},
#  {'Nepal Electricity Authority', 'Subisu Cablenet '},
#  {'Nepal Electricity Authority'},
#  {'NMB Bank Visa Credit Card',
#   'NT Landline Payment',
#   'Nabil Bank Credit Card',
#   'Send Money',
#   'Sim TV',
#   'WorldLink NETTV',
#   'WorldLink Pay'},
#  {'Dish Home Topup',
#   'Epay Donation',
#   'NT ADSL Topup - Unlimited',
#   'Nepal Electricity Authority',
#   'QFX Chhaya Centre',
#   'QFX Cinemas',
#   'Send Money',
#   'Smart Cell Topup',
#   'Vianet',
#   'WorldLink Pay'},
#  {'NCELL TOPUP',
#   'NIC Asia Bank Credit Card',
#   'QFX Cinemas',
#   'Siddhartha Bank Credit Card',
#   'Worldlink'},
#  {'Nepal Electricity Authority', 'QFX Cinemas'},
#  {'NT ADSL Topup - Unlimited', 'NT Landline Payment'},
#  {'Dish Home Topup',
#   'NT ADSL Topup - Unlimited',
#   'NT Landline Payment',
#   'Nepal Electricity Authority',
#   'QFX Cinemas',
#   'Send Money',
#   'WorldLink Pay'},
#  {'BUDDHA AIR',
#   'Inception Collection Center',
#   'NT Landline Payment',
#   'Nepal Electricity Authority',
#   'Radius Communications',
#   'YETI AIRLINES'},
#  {'Bussewa.com',
#   'NT ADSL Topup - Unlimited',
#   'NT Landline Payment',
#   'Nepal Electricity Authority',
#   'Send Money',
#   'Vianet'},
#  {'Net TV',
#   'QFX Chhaya Centre',
#   'QFX Cinemas',
#   'Send Money',
#   'Vianet',
#   'WorldLink Pay'},
#  {'NT ADSL Topup - Unlimited', 'Send Money'},
#  {'QFX Cinemas', 'Reecharger.com', 'Sim TV'},
#  {'BUDDHA AIR', 'Vianet', 'WorldLink NETTV'},
#  {'QFX Cinemas', 'Sim TV'},
#  {'Dish Home Topup', 'Send Money', 'Smart Cell Topup'},
#  {'Mero TV Mobile Payment',
#   'NT ADSL Topup - Unlimited',
#   'NT ADSL Topup - Volume Based'},
#  {'Classic Tech Pvt. Ltd.', 'Music Nepal'},
#  {'Tootle', 'WorldLink NETTV'},
#  {'NT CDMA Postpaid Topup',
#   'NT Landline Payment',
#   'Smart Cell Recharge Card',
#   'Smart Cell Topup'},
#  {'NCELL TOPUP'},
#  {'Lekhnath Khanepani', 'NT Landline Payment', 'Nepal Electricity Authority'},
#  {'NT Landline Payment',
#   'Nepal Electricity Authority',
#   'Net TV',
#   'QFX Jalma Bharatpur',
#   'Siddhartha Bank Credit Card'},
#  {'NCCS Chandole', 'Reecharger.com', 'Send Money'},
#  {'NT ADSL Topup - Unlimited',
#   'NT CDMA Prepaid Topup',
#   'NT Landline Payment',
#   'NT Recharge Card',
#   'Nepal Electricity Authority',
#   'Send Money'},
#  {'BUDDHA AIR',
#   'Bigmovies',
#   'Epay Donation',
#   'Mynepshop.com',
#   'NT Recharge Card',
#   'WorldLink Pay'},
#  {'Dish Home Topup', 'WorldLink Pay'},
#  {'Nepal Electricity Authority'},
#  {'Dish Home Topup', 'Net TV', 'QFX Cinemas', 'Vianet', 'WorldLink Pay'},
#  {'CAN', 'NT Landline Payment'},
#  {'Send Money'},
#  {'Inception Collection Center'},
#  {'BUDDHA AIR', 'QFX Chhaya Centre', 'Send Money', 'Vianet', 'Yeti Airlines'},
#  {'Dish Home Topup',
#   'Global IME Visa Credit Cards',
#   'Kumari Bank Credit Card ',
#   'Nabil Bank Credit Card',
#   'Vianet'},
#  {'BUDDHA AIR', nan},
#  {'Saurya Airlines', 'Sharesansar'},
#  {'Bhoj'},
#  {'NEPAL MEDICAL COUNCIL - TOKEN', 'NEPAL NURSING COUNCIL - Online Payment'},
#  {'BUDDHA AIR',
#   'International Airlines',
#   'Nepal Electricity Authority',
#   'Send Money',
#   'Subisu Cablenet ',
#   'YETI AIRLINES'},
#  {'Dish Home Topup', 'NT Landline Payment'},
#  {'Kaspersky Antivirus', 'WorldLink Pay'},
#  {'NT Landline Payment'},
#  {'NT ADSL Topup - Unlimited',
#   'Nepal Electricity Authority',
#   'Oho Domain',
#   'QFX Chhaya Centre',
#   'QFX Cinemas',
#   'Radius Communications'},
#  {'Send Money'},
#  {'Send Money'},
#  {'Nepal Electricity Authority', 'Oho Domain'},
#  {'Nepal Electricity Authority', 'Subisu Cablenet '},
#  {'Dish Home Recharge Card', 'NT ADSL Topup - Unlimited'},
#  {'Nepal Electricity Authority', 'Send Money'},
#  {'Send Money'},
#  {'Send Money'},
#  {'Mero TV'},
#  {'QFX Chhaya Centre'},
#  {'Worldlink'},
#  {'BUDDHA AIR', 'Oho Domain', 'Send Money', 'Subisu Cablenet '},
#  {'Buddha Air Mobile App',
#   'NCELL PRO',
#   'NCELL TOPUP',
#   'NT ADSL Topup - Unlimited',
#   'NT Recharge Card',
#   'Nepal Electricity Authority',
#   'Send Money'},
#  {'BUDDHA AIR',
#   'NT Landline Payment',
#   'NT Recharge Card',
#   'Nepal Electricity Authority'},
#  {'CAN',
#   'Dish Home Topup',
#   'NT ADSL Topup - Unlimited',
#   'Net TV',
#   'Oho Domain',
#   'Send Money',
#   'Tootle',
#   'WorldLink Pay'},
#  {'BUDDHA AIR', 'NT Landline Payment', 'WorldLink NETTV', 'YETI AIRLINES'},
#  {'Tootle'},
#  {'Epay Donation',
#   'NCELL TOPUP',
#   'Nepal Electricity Authority',
#   'Send Money',
#   'Sim TV',
#   'Worldlink'},
#  {'Dish Home Topup', 'FCube Cinemas', 'NT ADSL Topup - Unlimited'},
#  {'FCube Cinemas',
#   'Nepal Electricity Authority',
#   'Net TV',
#   'Send Money',
#   'Tootle',
#   'Vianet'},
#  {'BSR Movies', "Q's Cinemas", 'Shree Airlines B2C', 'YETI AIRLINES'},
#  {'Dish Home Topup',
#   'NT Landline Payment',
#   'Nepal Electricity Authority',
#   'Net TV',
#   'QFX Cinemas',
#   'Send Money'},
#  {'BUDDHA AIR', 'NT ADSL Topup - Unlimited', 'SHREE AIRLINES'},
#  {'Send Money'},
#  {'CAN',
#   'NCELL TOPUP',
#   'NT ADSL Topup - Unlimited',
#   'NT Landline Payment',
#   'Nepal Electricity Authority',
#   'Send Money',
#   'Sim TV',
#   'WorldLink Pay'},
#  {'NT Landline Payment', 'Nepal Electricity Authority'},
#  {'YETI AIRLINES'},
#  {'WorldLink NETTV'},
#  {'Buddha Air Mobile App',
#   'Send Money',
#   'Worldlink',
#   'YETI AIRLINES',
#   'Yeti Airlines'},
#  {'BUDDHA AIR',
#   'MIDTOWN CINEMAS',
#   'NT CDMA',
#   'NT Landline Payment',
#   'Nepal Electricity Authority',
#   'QFX  Cineplex Pokhara',
#   'SIMRIK AIRLINES',
#   'YETI AIRLINES'},
#  {'BUDDHA AIR',
#   'Dish Home Recharge Card',
#   'Dish Home Topup',
#   'International Airlines',
#   'NT Landline Payment',
#   'Smart Cell Topup',
#   'WorldLink NETTV'},
#  {'Nepal Electricity Authority', 'QFX Cinemas'},
#  {'NT Landline Payment', 'Net TV', 'WorldLink Pay'},
#  {'NT Landline Payment', 'Nabil Bank Credit Card', 'Sim TV', 'WorldLink Pay'},
#  {'Dish Home Topup', 'Machhapuchchhre Bank Credit Card'},
#  {'Dish Home Topup', 'Send Money'},
#  {'NT Landline Payment', 'QFX Cinemas', 'Send Money', 'Vianet'},
#  {'International Airlines', 'NT Recharge Card', 'WorldLink Pay'},
#  {'Nepal Electricity Authority', 'Send Money', 'Smart Cell Topup', nan},
#  {'Tootle'},
#  {'SHREE AIRLINES', 'Send Money'},
#  {'NT Landline Payment', 'Nepal Electricity Authority'},
#  {'Send Money'},
#  {'Nabil Bank Credit Card'},
#  {'QFX Cinemas', 'Vianet'},
#  {'Kaspersky Antivirus',
#   'Oho Domain',
#   'Radius Communications',
#   'Vianet',
#   'WorldLink Pay'},
#  {'NT Landline Payment', 'Send Money'},
#  {'NT ADSL Topup - Unlimited', 'QFX Cinemas', 'Send Money'},
#  {'Send Money', 'WorldLink Pay'},
#  {'Dish Home Topup',
#   'FCube Cinemas',
#   'NCELL TOPUP',
#   'Net TV',
#   "Q's Cinemas",
#   'QFX Chhaya Centre',
#   'QFX Cinemas',
#   'Send Money',
#   'WorldLink Pay',
#   'eSewapasal'},
#  {'Classic Tech Pvt. Ltd.',
#   'DISHHOME RECHARGE',
#   'Global IME Visa Credit Cards',
#   'Laxmi Bank Credit Card',
#   'NT Landline Payment',
#   'Nabil Bank Credit Card',
#   'Siddhartha Bank Credit Card',
#   'Sim TV'},
#  {'NT Landline Payment', 'Nepal Electricity Authority'},
#  {'Nepal Electricity Authority', 'Sim TV', 'WorldLink Pay'},
#  {'NT CDMA Prepaid Topup',
#   'NT Landline Payment',
#   'Send Money',
#   'Subisu Cablenet '},
#  {'Dish Home Topup',
#   'FCube Cinemas',
#   'NT Landline Payment',
#   'NT Recharge Card',
#   'Nepal Electricity Authority',
#   'Send Money',
#   'Vianet'},
#  {'Dish Home Topup', 'Nepal Electricity Authority', 'QFX Cinemas'},
#  {'QFX Chhaya Centre', 'SHREE AIRLINES', 'Vianet', 'YETI AIRLINES'},
#  {'Bigmovies',
#   'FCube Cinemas',
#   'Inception Collection Center',
#   'Oho Domain',
#   'Reecharger.com',
#   'Worldlink'},
#  {'Worldlink'},
#  {'Citizens Bank Credit Card',
#   'Dish Home Topup',
#   'FCube Cinemas',
#   'NCELL TOPUP',
#   'NT CDMA',
#   'Nepali Paisa',
#   'Vianet'},
#  {'Epay Donation',
#   'NT ADSL Topup - Unlimited',
#   'ONLINEKINMEL.COM',
#   'Send Money',
#   'Subisu Cablenet '},
#  {'Nepal Electricity Authority', 'Send Money'},
#  {'DISHHOME RECHARGE',
#   'Dish Home Recharge Card',
#   'NEPAL NURSING COUNCIL - LICENSE EXAM',
#   'NT Landline Payment',
#   'Nabil Bank Credit Card',
#   'Nepal Electricity Authority',
#   'Send Money',
#   'Sim TV'},
#  {'Nepal Electricity Authority', 'QFX Cinemas'},
#  {'ADSL Bill Payment',
#   'BUDDHA AIR',
#   'Dish Home Topup',
#   'Epay Donation',
#   'Mytrip2nepal.com',
#   'NCELL PRO',
#   'NCELL TOPUP',
#   'NT ADSL Topup - Volume Based',
#   'NT Landline Payment',
#   'NT Recharge Card',
#   'Nepal Electricity Authority',
#   'Net TV',
#   'Rasa Gift Centre',
#   'Send Money',
#   'WorldLink Pay'},
#  {'FCube Cinemas',
#   'Oho Domain',
#   'WorldLink NETTV',
#   'WorldLink Pay',
#   'Worldlink'},
#  {'BUDDHA AIR',
#   'DISHHOME RECHARGE',
#   'Dish Home Topup',
#   'NT ADSL Topup - Unlimited',
#   'Nepal Electricity Authority',
#   'SHREE AIRLINES',
#   'Saurya Airlines',
#   'Send Money',
#   'YETI AIRLINES'},
#  {'WorldLink Pay'},
#  {'BUDDHA AIR',
#   'Namaste Kapilvastu',
#   'Net TV Recharge Card for Mobile App',
#   'Send Money',
#   'YETI AIRLINES'},
#  {'QFX Cinemas', 'Send Money', 'Tootle'},
#  {'Kaspersky Antivirus', 'Nepal Electricity Authority', 'WorldLink NETTV'},
#  {'NT Landline Payment'},
#  {'Nepal Electricity Authority', 'WorldLink Pay'},
#  {'Oho Domain'},
#  {'Send Money'},
#  {'NCELL TOPUP', 'Nepal Electricity Authority'},
#  {'Dish Home Topup', 'Vianet', 'WorldLink Pay'},
#  {'Nepal Electricity Authority',
#   'QFX Cinemas',
#   'Send Money',
#   'Subisu Cablenet '},
#  {'Itel Communication ', 'Mero TV'},
#  {'Cash Out',
#   'Consumer Online Details',
#   'NT Landline Payment',
#   'Nepal Electricity Authority',
#   'Send Money',
#   'Vianet'},
#  {'Dish Home Topup',
#   'NT ADSL Topup - Unlimited',
#   'NT Landline Payment',
#   'Nepal Electricity Authority'},
#  {'Inception Collection Center',
#   'Merolagani.com',
#   'NT Landline Payment',
#   'Nepal Electricity Authority',
#   'Radius Communications',
#   'Send Money',
#   'WorldLink NETTV',
#   'WorldLink Pay'},
#  {'Send Money'},
#  {'Dish Home Recharge Card',
#   'Dish Home Topup',
#   'NT ADSL Topup - Unlimited',
#   'NT Landline Payment',
#   'NT Recharge Card',
#   'Send Money'},
#  {'Dish Home Topup', 'NCELL TOPUP', 'Send Money'},
#  {'Send Money'},
#  {'NCELL TOPUP'},
#  {'Bussewa.com',
#   'Dish Home Recharge Card',
#   'NT Recharge Card',
#   'Nepal Electricity Authority',
#   'Send Money',
#   'Sharesansar',
#   'YETI AIRLINES'},
#  {'BUDDHA AIR',
#   'Dish Home Topup',
#   'NCELL TOPUP',
#   'NT CDMA Postpaid Topup',
#   'NT CDMA Prepaid Topup',
#   'NT Recharge Card',
#   'QFX Chhaya Centre',
#   'SHREE AIRLINES',
#   'Send Money',
#   'Subisu Cablenet ',
#   'Vianet',
#   'YETI AIRLINES'},
#  {'QFX Cinemas'},
#  {'Nepal Electricity Authority', 'Send Money'},
#  {'Dish Home Topup', 'QFX Cinemas', 'Vianet'},
#  {'Send Money'},
#  {'BUDDHA AIR',
#   'Broadlink Recharge Card',
#   'Classic Tech Pvt. Ltd.',
#   'Epay Donation',
#   'NCELL TOPUP',
#   'ONLINEKINMEL.COM',
#   'QFX Cinemas',
#   'Send Money',
#   'WorldLink Pay'},
#  {'NT Landline Payment', 'WorldLink NETTV', 'WorldLink Pay'},
#  {'NT Landline Payment', 'Vianet'},
#  {'NT Recharge Card',
#   'Net TV',
#   "Q's Cinemas",
#   'QFX Chhaya Centre',
#   'QFX Cinemas',
#   'Send Money',
#   'WorldLink Pay',
#   'Worldlink'},
#  {'NCELL TOPUP'},
#  {'BUDDHA AIR',
#   'Buymandu.com',
#   'Citizens Bank Credit Card',
#   'Global IME Visa Credit Cards',
#   'Laxmi Bank Credit Card',
#   'Mero TV',
#   'Nabil Bank Credit Card',
#   'Net TV',
#   'Prabhu Bank Credit Card ',
#   'QFX Cinemas',
#   'Radius Communications',
#   'Send Money',
#   'Siddhartha Bank Credit Card',
#   'Tootle',
#   'Vianet',
#   'Worldlink',
#   'YETI AIRLINES'},
#  {'NT Landline Payment', 'Send Money', 'Sim TV'},
#  {'Dish Home Topup', 'Vianet'},
#  {'BUDDHA AIR',
#   'NCELL PRO',
#   'NCELL TOPUP',
#   'Nepal Electricity Authority',
#   'Oho Domain',
#   'Send Money'},
#  {'Vianet'},
#  {'BUDDHA AIR',
#   'Dish Home Topup',
#   'FCube Cinemas',
#   'Laxmi Bank Credit Card',
#   'Nepal Electricity Authority',
#   'Radius Communications',
#   'SHREE AIRLINES',
#   'Saurya Airlines'},
#  {'Dish Home Topup',
#   'NT Landline Payment',
#   'Nepal Electricity Authority',
#   'Net TV',
#   "Q's Cinemas",
#   'QFX Cinemas',
#   'WorldLink Pay'},
#  {'BUDDHA AIR'},
#  {'NT Landline Payment', 'Nepal Electricity Authority'},
#  {'Dish Home Topup', 'NT CDMA Prepaid Topup', 'Send Money'},
#  {'BUDDHA AIR',
#   'FCube Cinemas',
#   'Mero TV',
#   'NT Landline Payment',
#   'WorldLink Pay',
#   'Worldlink',
#   nan},
#  {'YETI AIRLINES'},
#  {'NT ADSL Topup - Unlimited',
#   'NT ADSL Topup - Volume Based',
#   'NT CDMA Prepaid Topup',
#   'Nepal Electricity Authority'},
#  {'Send Money'},
#  {'NAMS-online payment', 'QFX Cinemas', 'WorldLink NETTV'},
#  {'Itel Communication '},
#  {'Dish Home Recharge Card',
#   'Global IME Capital',
#   'QFX Chhaya Centre',
#   'Vianet',
#   nan},
#  {'Net TV', 'Tootle'},
#  {'Dish Home Topup', 'NT ADSL Topup - Unlimited', 'QFX Cinemas'},
#  {'Send Money', 'Vianet'},
#  {'NT Landline Payment', 'Nepal Electricity Authority', 'Shivnagar Khanepani'},
#  {'Merojob'},
#  {'Net TV'},
#  {'NCELL TOPUP', 'Send Money'},
#  {'Dish Home Topup',
#   'NT ADSL Topup - Unlimited',
#   'NT Landline Payment',
#   'Nabil Bank Credit Card',
#   "Q's Cinemas",
#   'QFX Cinemas',
#   'WorldLink Pay'},
#  {'Nepal Electricity Authority'},
#  {'NT Landline Payment',
#   'Nepal Electricity Authority',
#   'Net TV',
#   'Send Money',
#   'Sim TV',
#   'Vianet',
#   'Worldlink'},
#  {'BUDDHA AIR',
#   'NT Landline Payment',
#   'Nepal Electricity Authority',
#   'QFX Chhaya Centre'},
#  {'Dish Home Topup'},
#  {'BUDDHA AIR',
#   'Dish Home Topup',
#   'Nepal Electricity Authority',
#   'Subisu Cablenet ',
#   'Vianet'},
#  {'Dish Home Recharge Card', 'Dish Home Topup', 'NT ADSL Topup - Unlimited'},
#  {'NT Landline Payment',
#   'Nepal Electricity Authority',
#   'Radius Communications',
#   'Send Money',
#   'Sim TV',
#   'Vianet'},
#  {'Buymandu.com', 'Send Money', 'Sharesansar'},
#  {'Nepal Electricity Authority', 'Subisu Cablenet '},
#  {'BUDDHA AIR',
#   'NT Landline Payment',
#   'Nepal Electricity Authority',
#   'SHREE AIRLINES',
#   'Send Money',
#   'YETI AIRLINES'},
#  {'Dish Home Topup',
#   'Nepal Electricity Authority',
#   'Net TV',
#   'QFX Cinemas',
#   'Tootle'},
#  {'FCube Cinemas', 'NT ADSL Topup - Unlimited', 'QFX Cinemas'},
#  {'Dish Home Topup',
#   'NCELL TOPUP',
#   'NT Landline Payment',
#   'Nabil Bank Credit Card',
#   'Nepal Electricity Authority',
#   'Vidhya Sanskar School',
#   'WorldLink Pay'},
#  {'BUDDHA AIR',
#   'Dish Home Topup',
#   'Nabil Bank Credit Card',
#   'Net TV',
#   'Vianet'},
#  {'WorldLink Pay'},
#  {'WorldLink NETTV'},
#  {'QFX Cinemas'},
#  {'Buddha Air', 'NT Recharge Card'},
#  {'BUDDHA AIR', 'NT Landline Payment'},
#  {'BUDDHA AIR',
#   'Epay Donation',
#   'Merojob',
#   'NCELL TOPUP',
#   'NT ADSL Topup - Unlimited',
#   'NT Landline Payment',
#   "Q's Cinemas",
#   'QFX Cinemas',
#   'Radius Communications',
#   'SHREE AIRLINES',
#   'Saurya Airlines',
#   'Send Money',
#   'Sim TV',
#   'Vianet',
#   'Worldlink'},
#  {'NT ADSL Topup - Unlimited',
#   'NT Landline Payment',
#   'Nepal Electricity Authority'},
#  {'BUDDHA AIR',
#   'Nepal Electricity Authority',
#   'Radius Communications',
#   'Subisu Cablenet '},
#  {'BUDDHA AIR',
#   'Dish Home Topup',
#   'Nepal Electricity Authority',
#   'Send Money'},
#  {'NT Landline Payment', 'Nepal Electricity Authority', 'Worldlink'},
#  {'Broadlink Recharge Card',
#   'Dish Home Recharge Card',
#   'NCELL TOPUP',
#   'Nepal Electricity Authority',
#   'Send Money',
#   'Vianet',
#   'YETI AIRLINES'},
#  {'WorldLink NETTV'},
#  {'Bigmovies',
#   'FCube Cinemas',
#   'Midwest',
#   'NT Landline Payment',
#   'Paschim Nepal Bus(pnbbs)',
#   'QFX Cinemas',
#   'Saurya Airlines',
#   'Send Money',
#   'Travel Nepal Bus Service',
#   'Vianet',
#   'YETI AIRLINES'},
#  {'Net TV', 'QFX Cinemas', 'Send Money'},
#  {'BUDDHA AIR', 'Dish Home Topup', 'Nabil Bank Credit Card', 'QFX Cinemas'},
#  {'QFX Cinemas', 'Send Money', 'Vianet'},
#  {'BUDDHA AIR',
#   'Bussewa.com',
#   'Nepal Electricity Authority',
#   'QFX Chhaya Centre',
#   'SIMRIK AIRLINES',
#   'Send Money',
#   'Vianet'},
#  {'NT Landline Payment',
#   'Nepal Electricity Authority',
#   'QFX Chhaya Centre',
#   'WorldLink NETTV'},
#  {'Net TV', 'Send Money'},
#  {'NAMS-TOKEN', 'Nepal Electricity Authority'},
#  {'Dish Home Topup',
#   'NT Landline Payment',
#   'Nepal Electricity Authority',
#   'QFX Cinemas',
#   'Send Money'},
#  {'Dish Home Topup', 'Nepal Electricity Authority'},
#  {'NT Landline Payment',
#   'Nepal Electricity Authority',
#   'Send Money',
#   'Smart Cell Topup',
#   'Subisu Cablenet ',
#   'WorldLink Pay'},
#  {'BUDDHA AIR',
#   'Dish Home Topup',
#   'NT Landline Payment',
#   'Nepal Electricity Authority',
#   'SHREE AIRLINES'},
#  {'Send Money'},
#  {'Ecircle Classified Advertise',
#   'Epay Donation',
#   'NT Landline Payment',
#   'Send Money',
#   'WorldLink Pay'},
#  {'Dish Home Topup',
#   'NT ADSL Topup - Unlimited',
#   'Send Money',
#   'WorldLink Pay',
#   'Worldlink'},
#  {'Dish Home Topup',
#   'Kathmandu Pragya Kunja School',
#   'Nepal Electricity Authority',
#   'WorldLink Pay',
# ...
#  {'WorldLink NETTV'},
#  {'Dish Home Topup', 'WorldLink Pay'},
#  {'Dish Home Topup', 'Send Money'},
#  {'NT ADSL Topup - Unlimited'},
#  {'QFX Cinemas', 'Send Money', 'Vianet'},
#  {'Nepal Electricity Authority'},
#  {'Worldlink'},
#  {'Send Money'},
#  {'BUDDHA AIR',
#   'Classic Tech Pvt. Ltd.',
#   'Dish Home Topup',
#   'NT Landline Payment',
#   'Nepal Electricity Authority',
#   'Send Money',
#   'YETI AIRLINES'},
#  {'Cash Out',
#   'NT CDMA Prepaid Topup',
#   'Nepal Electricity Authority',
#   'Send Money'},
#  {'Dish Home Topup',
#   'Nepal Electricity Authority',
#   'QFX Cinemas',
#   'Send Money'},
#  {'Dish Home Topup', 'Nepal Electricity Authority'},
#  {'Dish Home Topup',
#   'Inception Collection Center',
#   'Net TV',
#   'Send Money',
#   'Worldlink'},
#  {'BUDDHA AIR',
#   'Bigmovies',
#   'QFX Cinemas',
#   'SHREE AIRLINES',
#   'Saurya Airlines',
#   'Send Money',
#   'Smart Cell Topup',
#   'WorldLink Pay'},
#  {'NT Landline Payment', 'Nepal Electricity Authority', 'QFX Cinemas'},
#  {'Nepal Electricity Authority',
#   'Reecharger.com',
#   'WorldLink NETTV',
#   'WorldLink Pay'},
#  {'QFX Chhaya Centre', 'QFX Cinemas', 'Send Money', 'WorldLink Pay'},
#  {'Dish Home Topup',
#   'NT ADSL Topup - Unlimited',
#   'NT Landline Payment',
#   'Send Money',
#   'Subisu Cablenet '},
#  {'Bigmovies',
#   "Q's Cinemas",
#   'QFX Chhaya Centre',
#   'QFX Cinemas',
#   'Smart Cell Topup'},
#  {'Mero TV'},
#  {'NCELL TOPUP', 'Nepal Electricity Authority'},
#  {'BUDDHA AIR',
#   'Nabil Bank Credit Card',
#   'Nepal Electricity Authority',
#   "Nepal Engineer's Association",
#   'Radius Communications',
#   'Send Money',
#   'YETI AIRLINES'},
#  {'Global IME Capital',
#   'NT Landline Payment',
#   'Nepal Electricity Authority',
#   'QFX Cinemas',
#   'Subisu Cablenet '},
#  {'Inception Collection Center',
#   'Midwest',
#   'Nabil Bank Credit Card',
#   'Send Money'},
#  {'NT ADSL Topup - Unlimited',
#   'NT Landline Payment',
#   'Nepal Electricity Authority'},
#  {'BUDDHA AIR',
#   'NT ADSL Topup - Unlimited',
#   'Namaste Kapilvastu',
#   'Paschim Nepal Bus(pnbbs)',
#   'Send Money',
#   'Subisu Cablenet ',
#   'Vianet'},
#  {'NT Landline Payment'},
#  {'Paschim Nepal Bus(pnbbs)'},
#  {'FCube Cinemas', 'Nepal Electricity Authority', 'QFX Cinemas'},
#  {'Nepal Electricity Authority'},
#  {'Smart Cell Topup'},
#  {'Dish Home Topup', 'QFX Cinemas'},
#  {'Dish Home Topup',
#   'NT ADSL Topup - Unlimited',
#   'NT Recharge Card',
#   'Nabil Bank Credit Card',
#   'Net TV Recharge Card for Mobile App',
#   'Reecharger.com',
#   'Send Money',
#   'Vianet',
#   'WorldLink Pay'},
#  {'Nepal Electricity Authority', 'Oho Domain', 'Send Money', 'WorldLink Pay'},
#  {'Dish Home Topup',
#   'QFX Cinemas',
#   'SHREE AIRLINES',
#   'Send Money',
#   'YETI AIRLINES'},
#  {'NT CDMA Prepaid Topup',
#   'NT Recharge Card',
#   'Send Money',
#   'Subisu Cablenet ',
#   'Websurfer.com',
#   'WorldLink Pay'},
#  {'QFX Cinemas', 'Send Money'},
#  {'Global IME Visa Credit Cards',
#   "Q's Cinemas",
#   'QFX Chhaya Centre',
#   'Vianet'},
#  {'Consumer Online Details'},
#  {'BUDDHA AIR', 'QFX Cinemas'},
#  {'NT Recharge Card', 'Oho Domain'},
#  {'Hamro Doctor', 'Mero TV'},
#  {'Merolagani.com'},
#  {'Dish Home Topup', 'Net TV Recharge Card for Mobile App'},
#  {'NT Landline Payment',
#   'Nepal Electricity Authority',
#   'QFX Cinemas',
#   'Radius Communications',
#   'WorldLink NETTV'},
#  {'Nepal Electricity Authority'},
#  {'Nepal Electricity Authority'},
#  {'Buddha Air',
#   'Net TV',
#   'QFX Bageshwori Nepalgunj',
#   'Send Money',
#   'WorldLink Pay'},
#  {'Send Money'},
#  {'NCELL PRO', 'Nepal Electricity Authority', 'Send Money'},
#  {'QFX Cinemas'},
#  {'Nepal Electricity Authority'},
#  {'WorldLink Pay'},
#  {'BUDDHA AIR', 'Send Money'},
#  {'NT ADSL Topup - Unlimited',
#   'NT Landline Payment',
#   'Nepal Electricity Authority'},
#  {'Send Money', 'WorldLink Pay'},
#  {'BUDDHA AIR',
#   'Dish Home Topup',
#   'NT ADSL Topup - Unlimited',
#   'NT Landline Payment',
#   'Nepal Electricity Authority',
#   'Send Money',
#   'WorldLink NETTV'},
#  {'NT Landline Payment',
#   'Nabil Bank Credit Card',
#   'Reecharger.com',
#   'Send Money',
#   'WorldLink Pay'},
#  {'Dish Home Topup', 'Nepal Electricity Authority', 'Send Money', 'Vianet'},
#  {'NT Landline Payment', 'QFX Cinemas', 'Vianet', 'WorldLink Pay'},
#  {'NT Landline Payment', 'Nepal Electricity Authority'},
#  {'NT ADSL Topup - Unlimited',
#   'NT Landline Payment',
#   'Nepal Electricity Authority',
#   'QFX Cinemas',
#   'Send Money',
#   'Subisu Cablenet '},
#  {'NT Landline Payment', 'Worldlink', nan},
#  {'Buddha Air Mobile App',
#   'NT CDMA',
#   'Nepal Electricity Authority',
#   'WorldLink Pay',
#   'Worldlink',
#   'YETI AIRLINES'},
#  {'Send Money'},
#  {'Reecharger.com'},
#  {'Send Money', 'Sim TV', 'Subisu Cablenet '},
#  {'NT Landline Payment'},
#  {'Epay Donation', "Q's Cinemas", 'Worldlink'},
#  {'QFX Chhaya Centre', 'QFX Cinemas', 'Vianet'},
#  {'NT ADSL Topup - Unlimited'},
#  {'Nepal Electricity Authority', 'Send Money'},
#  {'Net TV'},
#  {'BUDDHA AIR',
#   'Ecircle Classified Advertise',
#   'Epay Donation',
#   'NT ADSL Topup - Unlimited',
#   'Net TV Recharge Card for Mobile App',
#   'Send Money',
#   'Vianet',
#   nan},
#  {'NT Landline Payment',
#   'Nepal Electricity Authority',
#   'Siddhartha Capital Direct Pay',
#   'Sim TV',
#   'WorldLink Pay'},
#  {'Net TV Recharge Card for Mobile App', 'Sim TV'},
#  {'Dish Home Topup'},
#  {'BUDDHA AIR',
#   'Dish Home Topup',
#   'NT ADSL Topup - Unlimited',
#   'SHREE AIRLINES',
#   'Saurya Airlines',
#   'Send Money',
#   'YETI AIRLINES'},
#  {'Dish Home Topup', 'NT Landline Payment', 'Nepal Electricity Authority'},
#  {'NT ADSL Topup - Unlimited'},
#  {'BUDDHA AIR', 'CAN', 'Dish Home Topup', 'NT Landline Payment', 'Send Money'},
#  {'NT Landline Payment'},
#  {'Bigmovies',
#   'NT Landline Payment',
#   'Nepal Electricity Authority',
#   'QFX Cinemas',
#   'Sim TV'},
#  {'Bigmovies',
#   'Net TV',
#   'QFX Chhaya Centre',
#   'QFX Cinemas',
#   'Send Money',
#   'WorldLink Pay'},
#  {'Dish Home Topup',
#   'NCELL TOPUP',
#   'Nepal Electricity Authority',
#   'Radius Communications',
#   'Send Money',
#   'Vianet'},
#  {'NT Landline Payment', 'Nepal Electricity Authority'},
#  {'Nepal Electricity Authority'},
#  {'Dish Home Recharge Card',
#   'NT Landline Payment',
#   'QFX Chhaya Centre',
#   'QFX Cinemas',
#   'Worldlink'},
#  {'QFX Chhaya Centre', 'Vianet'},
#  {'Vianet'},
#  {'Oho Domain', 'Send Money'},
#  {'NT Recharge Card'},
#  {'BUDDHA AIR',
#   'NT ADSL Topup - Unlimited',
#   'NT Landline Payment',
#   'Nepal Electricity Authority',
#   'Vianet',
#   'WorldLink Pay'},
#  {'BSR Movies',
#   'Epay Donation',
#   'Inception Collection Center',
#   'QFX Cinemas',
#   'Worldlink'},
#  {'Buddha Air',
#   'Dish Home Topup',
#   'NT Landline Payment',
#   'Nepal Electricity Authority',
#   'QFX Cinemas'},
#  {'Dish Home Topup', 'NT ADSL Topup - Unlimited', 'NT Landline Payment'},
#  {'NT ADSL Topup - Volume Based', 'Nepal Electricity Authority', 'Vianet'},
#  {'BUDDHA AIR',
#   'Dish Home Topup',
#   'Nepal Electricity Authority',
#   'Send Money',
#   'Worldlink'},
#  {'Nabil Bank Credit Card', 'QFX Cinemas', 'Send Money'},
#  {'BUDDHA AIR',
#   'Nepal Electricity Authority',
#   'Send Money',
#   'Vianet',
#   'WorldLink Pay',
#   nan},
#  {'Dish Home Topup',
#   'Merolagani.com',
#   'NCELL PRO',
#   'Nepali Paisa',
#   'WorldLink Pay'},
#  {'CAN',
#   'Dish Home Topup',
#   'NCELL TOPUP',
#   'Net TV Recharge Card for Mobile App',
#   'ONLINEKINMEL.COM',
#   'Send Money',
#   'Sharesansar',
#   'Sim TV'},
#  {'QFX Cinemas', 'Tootle'},
#  {'Dish Home Topup', 'Smart Cell Topup'},
#  {'Inception Collection Center',
#   'Nepal Electricity Authority',
#   'Oho Domain',
#   'Send Money'},
#  {'Nepal Electricity Authority', 'Vianet'},
#  {'Oho Domain', 'Sim TV', 'WorldLink Pay', 'Worldlink'},
#  {'Net TV'},
#  {'WorldLink NETTV', 'WorldLink Pay'},
#  {'NT Landline Payment'},
#  {'NT ADSL Topup - Unlimited',
#   'Nepal Electricity Authority',
#   'Net TV',
#   'Vidhya Sanskar School'},
#  {'NCCS Chandole', 'Nabil Bank Credit Card'},
#  {'Nepal Electricity Authority', 'Net TV', 'QFX Chhaya Centre', 'Worldlink'},
#  {'CAN',
#   'Epay Donation',
#   'NT ADSL Topup - Unlimited',
#   'NT Landline Payment',
#   'Nepal Electricity Authority'},
#  {'NT Landline Payment'},
#  {'Buddha Air Mobile App', 'Net TV'},
#  {'Dish Home Topup',
#   'NAMS-TOKEN',
#   'NT ADSL Topup - Unlimited',
#   'Net TV',
#   'Oho Domain',
#   'QFX Cinemas',
#   'Radius Communications',
#   'Send Money',
#   'Vianet'},
#  {'BUDDHA AIR',
#   'Dish Home Topup',
#   'NT CDMA Prepaid Topup',
#   'Nepal Electricity Authority',
#   'WorldLink Pay',
#   'Worldlink',
#   'YETI AIRLINES'},
#  {'Dish Home Recharge Card', 'QFX Cinemas'},
#  {'Send Money'},
#  {'NT Recharge Card', 'WorldLink Pay'},
#  {'BUDDHA AIR'},
#  {'NT ADSL Topup - Unlimited', 'Rasa Gift Centre'},
#  {'Lubhoo Khanepani'},
#  {'Send Money'},
#  {'NCELL TOPUP',
#   'NT Landline Payment',
#   'Nepal Electricity Authority',
#   'QFX Chhaya Centre',
#   'Vianet'},
#  {'NT ADSL Topup - Unlimited', 'Send Money'},
#  {'Nepal Electricity Authority'},
#  {'NT ADSL Topup - Unlimited',
#   'NT Landline Payment',
#   'Nepal Electricity Authority',
#   'Send Money',
#   'Sim TV'},
#  {'NT Landline Payment',
#   'Send Money',
#   'Subisu Cablenet ',
#   'Vianet',
#   'WorldLink Pay'},
#  {'QFX Cinemas', 'Send Money'},
#  {'Send Money', 'Worldlink'},
#  {'Bigmovies', 'Dish Home Topup', 'Send Money', 'WorldLink Pay', 'Worldlink'},
#  {'NT ADSL Topup - Volume Based'},
#  {'BSR Movies',
#   'FCube Cinemas',
#   'Nepal Electricity Authority',
#   'Net TV Recharge Card for Mobile App',
#   "Q's Cinemas",
#   'QFX Cinemas'},
#  {'Nepal Electricity Authority', 'Sim TV'},
#  {'FCube Cinemas', 'Global IME Capital', 'Smart Cell Topup'},
#  {'NT Landline Payment',
#   'Nepal Electricity Authority',
#   'Net TV',
#   'Oho Domain',
#   'QFX Chhaya Centre',
#   'QFX Cinemas',
#   'Send Money',
#   'Sim TV',
#   'Subisu Cablenet ',
#   'WorldLink Pay'},
#  {'QFX Cinemas'},
#  {'NT ADSL Topup - Unlimited',
#   'NT Landline Payment',
#   'Nepal Electricity Authority'},
#  {'Citizens Bank Credit Card',
#   'DISHHOME RECHARGE',
#   'Epay Donation',
#   'Global IME Capital',
#   'Global IME Visa Credit Cards',
#   'Inception Collection Center',
#   'Kumari Bank Credit Card ',
#   'Laxmi Bank Credit Card',
#   'Machhapuchchhre Bank Credit Card',
#   'Mega Bank Credit Card Bill Payment',
#   'NCELL PRO',
#   'NCELL TOPUP',
#   'NIC Asia Bank Credit Card',
#   'NMB Bank Visa Credit Card',
#   'Nabil Bank Credit Card',
#   'ONLINEKINMEL.COM',
#   'Prabhu Bank Credit Card ',
#   'Prime Commercial Bank Credit Card',
#   'Sanima Bank Credit Card',
#   'Send Money',
#   'Sharesansar',
#   'Siddhartha Bank Credit Card',
#   'Smart Cell Topup',
#   'Sunrise Bank Credit Card'},
#  {'Dish Home Topup', 'NT ADSL Topup - Unlimited', 'Reecharger.com'},
#  {'Dish Home Topup',
#   'NT Sim Card*****',
#   'Send Money',
#   'Sim TV',
#   'Smart Cell Topup',
#   'Vianet',
#   'WorldLink Pay'},
#  {'BUDDHA AIR',
#   'NT ADSL Topup - Unlimited',
#   'NT CDMA Prepaid Topup',
#   'NT Landline Payment',
#   'NT Recharge Card',
#   'Nepal Electricity Authority',
#   'QFX Jalma Bharatpur',
#   'SIMRIK AIRLINES',
#   'Send Money'},
#  {'Inception Collection Center', 'Send Money', 'WorldLink Pay'},
#  {'FCube Cinemas', 'Nepal Electricity Authority', 'Subisu Cablenet '},
#  {'Dish Home Topup',
#   "Q's Cinemas",
#   'QFX Cinemas',
#   'SHREE AIRLINES',
#   'Vianet',
#   'WorldLink Pay',
#   'Worldlink'},
#  {'NT ADSL Topup - Unlimited'},
#  {'Send Money'},
#  {'NT ADSL Topup - Unlimited',
#   'Nepal Electricity Authority',
#   'Sim TV',
#   'Vianet',
#   'WorldLink Pay'},
#  {'Merolagani.com', 'NT Landline Payment'},
#  {'Radius Communications', 'Send Money', 'Sharesansar'},
#  {'Classic Tech Pvt. Ltd.',
#   'NT ADSL Topup - Unlimited',
#   'Nepal Electricity Authority'},
#  {'Dish Home Topup',
#   'Epay Donation',
#   'NT CDMA Prepaid Topup',
#   'NT Recharge Card',
#   'Net TV'},
#  {'Send Money', 'Smart Cell Topup'},
#  {'Dish Home Topup',
#   'Epay Donation',
#   'HONS',
#   'Inception Collection Center',
#   'Mero TV',
#   'NCELL TOPUP',
#   'Net TV',
#   'Send Money',
#   'Vianet',
#   'Websurfer.com'},
#  {'DISHHOME RECHARGE',
#   'Laxmi Bank Credit Card',
#   'Nepal Electricity Authority',
#   'Subisu Cablenet '},
#  {"Q's Cinemas", 'Send Money'},
#  {'Dish Home Topup',
#   'Nepal Electricity Authority',
#   'Send Money',
#   'Smart Cell Topup',
#   'WorldLink Pay'},
#  {'BUDDHA AIR',
#   'Kaspersky Antivirus',
#   'NT Landline Payment',
#   'Net TV Recharge Card for Mobile App',
#   'QFX Chhaya Centre',
#   'WorldLink Pay'},
#  {'BUDDHA AIR',
#   'Dish Home Topup',
#   'NCELL TOPUP',
#   'NT ADSL Topup - Unlimited',
#   'NT CDMA',
#   'NT Landline Payment',
#   'QFX Cinemas',
#   'SHREE AIRLINES',
#   'Saurya Airlines',
#   'Send Money',
#   'Sharesansar',
#   'YETI AIRLINES'},
#  {'Bigmovies', 'Smart Cell Topup'},
#  {'Net TV Recharge Card for Mobile App',
#   'QFX Cinemas',
#   'Send Money',
#   'Vianet'},
#  {'NT Recharge Card', 'Send Money'},
#  {'Dish Home Topup', 'Net TV', 'QFX Cinemas', 'Sim TV'},
#  {'HONS'},
#  {'NT Landline Payment', "Q's Cinemas", 'QFX Cinemas', 'Tootle'},
#  {'BUDDHA AIR', 'HONS', 'QFX Chhaya Centre', 'QFX Cinemas', 'Sim TV'},
#  {'Send Money'},
#  {'Dish Home Topup', 'Kaspersky Antivirus', "Q's Cinemas", 'QFX Cinemas'},
#  {'Send Money'},
#  {'Yeti Airlines'},
#  {'NT ADSL Topup - Unlimited',
#   'NT Landline Payment',
#   'Send Money',
#   'Smart Cell Topup',
#   'WorldLink Pay'},
#  {'NT ADSL Topup - Unlimited',
#   'NT Landline Payment',
#   'Nepal Electricity Authority',
#   'Radius Communications',
#   'Send Money',
#   'Sharesansar',
#   'YETI AIRLINES'},
#  {'Bigmovies',
#   'Dish Home Topup',
#   'Nepal Electricity Authority',
#   'QFX Cinemas'},
#  {'BUDDHA AIR',
#   'Dish Home Topup',
#   'Kaspersky Antivirus',
#   'Mero TV',
#   'NT Landline Payment',
#   'Send Money',
#   'WorldLink Pay'},
#  {'Radius Communications'},
#  {'NT ADSL Topup - Unlimited'},
#  {'Nepal Electricity Authority'},
#  {'Bigmovies',
#   'CAN',
#   'Dish Home Topup',
#   'Epay Donation',
#   'Global IME Visa Credit Cards',
#   'NCELL PRO',
#   'Nabil Bank Credit Card',
#   'Net TV',
#   'Oho Domain',
#   'SHREE AIRLINES',
#   'Send Money',
#   'Vianet',
#   'WorldLink Pay'},
#  {'Global IME Capital', 'NT CDMA Prepaid Topup'},
#  {'Oho Domain'},
#  {'BUDDHA AIR',
#   'Bigmovies',
#   'SHREE AIRLINES',
#   'Saurya Airlines',
#   'YETI AIRLINES'},
#  {'NT CDMA Postpaid Topup'},
#  {'NT Landline Payment', 'Sharesansar'},
#  {'Dish Home Recharge Card',
#   'Nepal Electricity Authority',
#   'Send Money',
#   'Subisu Cablenet '},
#  {'Dish Home Topup', 'Namaste Kapilvastu', 'Nepal Electricity Authority'},
#  {'Dish Home Topup',
#   'NCELL TOPUP',
#   'Nepal Electricity Authority',
#   'Net TV Recharge Card for Mobile App',
#   'Send Money'},
#  {'Dish Home Topup',
#   'Oho Domain',
#   'Send Money',
#   'Siddhartha Bank Credit Card'},
#  {'Dish Home Topup',
#   'Net TV Recharge Card for Mobile App',
#   'QFX Cinemas',
#   'Send Money',
#   'Vianet',
#   'WorldLink Pay'},
#  {'Reecharger.com', 'Send Money'},
#  {'Dish Home Topup',
#   'NT Landline Payment',
#   'Nepal Electricity Authority',
#   'QFX Cinemas',
#   'WorldLink NETTV',
#   'WorldLink Pay',
#   'Worldlink'},
#  {'Nepal Electricity Authority', 'Send Money', 'WorldLink Pay'},
#  {'Global IME Capital', 'Worldlink'},
#  {'NCELL TOPUP',
#   'NT Landline Payment',
#   'Nepal Electricity Authority',
#   'Shivnagar Khanepani'},
#  {'Dish Home Topup',
#   'NCELL TOPUP',
#   'QFX Cinemas',
#   'Send Money',
#   'Sharesansar',
#   'Worldlink'},
#  {'NT Landline Payment', 'Nabil Bank Credit Card'},
#  {'NT ADSL Topup - Unlimited', 'NT Landline Payment'},
#  {'FCube Cinemas'},
#  {'NT Landline Payment', 'Sim TV'},
#  {'BUDDHA AIR',
#   'Dish Home Topup',
#   'Nepal Electricity Authority',
#   'Net TV Recharge Card for Mobile App',
#   'SHREE AIRLINES',
#   'Subisu Cablenet ',
#   'WorldLink Pay',
#   'YETI AIRLINES'},
#  {'Nepal Electricity Authority',
#   'Net TV',
#   'Net TV Recharge Card for Mobile App',
#   'QFX Cinemas'},
#  {'Bussewa Direct Pay',
#   'Bussewa.com',
#   'Kaspersky Antivirus',
#   'Net TV Recharge Card for Mobile App',
#   'Send Money'},
#  {'BUDDHA AIR',
#   'Dish Home Topup',
#   'Epay Donation',
#   'NT Recharge Card',
#   'Nepal Electricity Authority',
#   'ONLINEKINMEL.COM',
#   'Paschim Nepal Bus(pnbbs)',
#   'SHREE AIRLINES',
#   'Send Money',
#   'YETI AIRLINES'},
#  {'NT Landline Payment',
#   'Nepal Electricity Authority',
#   'Reecharger.com',
#   'Send Money',
#   'WorldLink Pay'},
#  {'Vianet'},
#  {'Laxmi Bank Credit Card',
#   'NT ADSL Topup - Unlimited',
#   'NT Landline Payment',
#   'Nepal Electricity Authority',
#   'Radius Communications',
#   'Send Money',
#   'Sim TV',
#   'Vianet',
#   'WorldLink Pay',
#   'Worldlink'},
#  {'BSR Movies', 'Dish Home Topup', 'NT Landline Payment'},
#  ...]

# %% [markdown]
# rules = apriori(dummy,min_support = .003,min_confidence = .2, min_lift = 3, min_length = 2)

# %%
import fim
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-20-e81cd0271d15> in <module>
# ----> 1 import fim
#
# ImportError: DLL load failed: The specified module could not be found.

# %%
pd.DataFrame(prep).to_excel('association_prepared.xlsx')

# %%
#result = fim.apriori(listed,supp= 1,target = 'a',report='l',)

# %%
#result

# %%
result = fim.eclat(listed,supp= 4,target = 'r',report='e',zmin = 2,conf = 50,eval = 'l')

# %%
for i in result[3][1]:
    print (i)

# %%
result_frame = pd.DataFrame(result)

# %%
result_frame

# %% [markdown]
# # DRAWBACKS

# %% [markdown]
# <ul>
#   <li>too large dataset with too many infrequent item set</li>
#   <li>Because of this, the support of frequent items becomes very small</li>
#   <li>Cannot learn interesting rules</li>
# </ul>

# %%
inp = cond[['fullname_X','product_name']]
inp.head()

# %%
haha = ((inp.product_name.value_counts()>1000)& (inp.product_name.value_counts()<3000))
keep=[]
for i in range(len(haha)):
    if haha[i] == True:
        keep.append(haha.index[i])

# %%
#inp.loc[list((inp.product_name.value_counts()<100).index.values)]

# %%
#counts = inp.groupby('fullname_X').product_name.apply()

# %%
inp = inp.loc[inp.product_name.isin(keep)]

# %%
prep = inp.groupby('fullname_X').product_name.apply(set)
listed = list(prep)

# %%
result = fim.eclat(listed,supp= 4,target = 'r',report='e',zmin = 2,conf = 1,eval = 'l')

# %%
result_frame = pd.DataFrame(result)

# %%
result_frame

# %% [markdown]
# # Tackling the drawbacks

# %% [markdown]
# # Removing top 3 highest purchased products, taking users who have made 50-200 transactions

# %%
import seaborn as sb

# %%
sb.distplot(data.fullname_X.value_counts())

# %% [markdown]
# <h2>Why do this?</h2>
# <ul>
#     <li>In this model, we have taken the users as the transactions. In actual, each item list is the items bought by the single person in a single purchase.</li>
#     <li>So, there exists a person who has bought 500 items as well as people who have bought 1 item only</li>
#     <li>In an actual one time transaciton, say in a supermarket, happening of such transaction is very rare</li>
#     <li>Since we are trying to emulate each transaction with the users, we have to take a little different approach</li>
#     <li>If we take all transaction, then the support for the items that were purchased very few times by very few users would be very less. In fact, the support for the frequent items would also be very less because of large number or transaction that have very few items.</li>
#     <li>That is why, we remove the top 3 highest purchased products. If a product appears in almost all of the transactions, we can recommend them to the customers without any problem. However, there is a problem, because this approach removes the product from the consequent, but also removes the product from the antecedent. Thus, removing potentially interesting rules as well</li>
#     <li>I took only the transaction(users in this case) that had 50-200 items. The number of items in transaction ranges from 1 to 500. If we believe in the gaussian distribution, we can also believe that the most frequent items occur between these numbers</li>
# <ul>

# %%
ranged = ((data.fullname_X.value_counts()>50)& (data.fullname_X.value_counts()<200))

# %%
ranged_frame=pd.DataFrame(ranged)

# %%
select = ranged_frame.loc[ranged_frame.fullname_X==True].index

# %%
selected_set = data.loc[data.fullname_X.isin(select)]

# %%
selected_set = selected_set.loc[(selected_set.product_name!='Ncell Topup') & (selected_set.product_name!='NT Postpaid Topup' )&(selected_set.product_name!='NT Prepaid Topup')]

# %%
prep = selected_set.groupby('fullname_X').product_name.apply(set)
listed = list(prep)

# %%
import fim

# %%
result = fim.eclat(listed,supp= 2,target = 'r',report='e',zmin = 1,conf = 70,eval = 'l')
result_frame = pd.DataFrame(result)

# %%
result_frame.head()

# %%
result_frame.to_excel('rulesAssociation.xlsx')
